# %% [markdown]
# # Pancreas Dataset

# %%
def make_if_dont_exist(folder_path,overwrite=False):
    """
    creates a folder if it does not exists
    input: 
    folder_path : relative path of the folder which needs to be created
    over_write :(default: False) if True overwrite the existing folder 
    """
    if os.path.exists(folder_path):
        
        if not overwrite:
            print(f"{folder_path} exists.")
        else:
            print(f"{folder_path} overwritten")
            shutil.rmtree(folder_path)
            os.makedirs(folder_path)

    else:
      os.makedirs(folder_path)
      print(f"{folder_path} created!")

# Maybe move path of preprocessed data directly on content - this may be signifcantely faster!
print("Current Working Directory {}".format(os.getcwd()))
path_dict = {
    "nnUNet_raw" : os.path.join(os.getcwd(), "nnUNet_raw"), 
    "nnUNet_preprocessed" : os.path.join(os.getcwd(), "nnUNet_preprocessed"), # 1 experiment: 1 epoch took 112s
    "nnUNet_results" : os.path.join(os.getcwd(), "nnUNet_results"),
    "RAW_DATA_PATH" : os.path.join(os.getcwd(), "original_data"), # This is used here only for convenience (not necessary for nnU-Net)!
}

# Write paths to environment variables
for env_var, path in path_dict.items():
  os.environ[env_var] = path 

# Check whether all environment variables are set correct!
for env_var, path in path_dict.items():
  if os.getenv(env_var) != path:
    print("Error:")
    print("Environment Variable {} is not set correctly!".format(env_var))
    print("Should be {}".format(path))
    print("Variable is {}".format(os.getenv(env_var)))
  make_if_dont_exist(path, overwrite=False)

print("If No Error Occured Continue Forward. =)")

# %%
# os.environ['nnUNet_raw_data_base'] = '/scratch/alif/nnUNet/original_data'
os.environ['nnUNet_raw_data_base'] = '/scratch/alif/nnUNet/nnUNet_raw_data_base'
os.environ['nnUNet_preprocessed'] = '/scratch/alif/nnUNet/nnUNet_preprocessed'
os.environ['RESULTS_FOLDER'] = '/scratch/alif/nnUNet/nnUNet_trained_models'

# %%
import os
import shutil
import json
import nibabel as nib
import numpy as np

# Define the source directories
source_train = 'original_data/UHN-MedImg3D-ML-quiz/train'
source_val = 'original_data/UHN-MedImg3D-ML-quiz/validation'
source_test = 'original_data/UHN-MedImg3D-ML-quiz/test'

# Define the target directories
target_base = 'original_data'
task_name = 'Task006_PancreasUHN'
target_task_dir = os.path.join(target_base, task_name)
images_tr_dir = os.path.join(target_task_dir, 'imagesTr')
images_ts_dir = os.path.join(target_task_dir, 'imagesTs')
labels_tr_dir = os.path.join(target_task_dir, 'labelsTr')

# Create the target directories if they don't exist
os.makedirs(images_tr_dir, exist_ok=True)
os.makedirs(images_ts_dir, exist_ok=True)
os.makedirs(labels_tr_dir, exist_ok=True)

# Initialize class mapping dictionary
class_mapping = {}

# Function to correct label values
def correct_labels(file_path):
    img = nib.load(file_path)
    data = img.get_fdata()

    print(f"Original unique labels in {file_path}: {np.unique(data)}")

    # Round to nearest valid value
    data_corrected = np.round(data)

    # Explicitly set near values to the exact intended labels
    data_corrected[np.isclose(data_corrected, 0.0)] = 0.0
    data_corrected[np.isclose(data_corrected, 1.0)] = 1.0
    data_corrected[np.isclose(data_corrected, 2.0)] = 2.0

    print(f"Corrected unique labels in {file_path}: {np.unique(data_corrected)}")
    print(f"----------------------------------------------------------------------\n\n")

    # Save the corrected label file to a temporary path
    temp_file_path = file_path.replace('.nii.gz', '_corrected.nii.gz')
    # corrected_img = nib.Nifti1Image(data_corrected, img.affine, img.header)
    corrected_img = nib.Nifti1Image(data_corrected, img.affine)
    
    nib.save(corrected_img, temp_file_path)
    
    return temp_file_path, np.unique(data_corrected), np.unique(data)

# Function to move files and record class labels
def move_files(source, image_dest, label_dest, class_mapping, case_id=0):
    
    if not label_dest:
        case_id = case_id
        total = len(os.listdir(source))
        for file in os.listdir(source):
            if file.endswith('0000.nii.gz'):
                src_image_file = os.path.join(source, file)

                case_str_image = f"case_{case_id:03d}_0000.nii.gz"
                dest_image_file = os.path.join(image_dest, case_str_image)
                shutil.copy(src_image_file, dest_image_file)
                
                print(f"""({case_id}/{total}) Source Image: {src_image_file} 
                      Dest Image: {dest_image_file}
                      Labels: No Class, Not Annotated
                """)
                case_id += 1
                
        return case_id
            
    else:
        case_id = case_id
        for subtype in os.listdir(source):
            subtype_path = os.path.join(source, subtype)
            if os.path.isdir(subtype_path):
                class_id = int(os.path.basename(subtype_path)[-1])
                total = len(os.listdir(subtype_path))
                for file in os.listdir(subtype_path):
                    if file.endswith('0000.nii.gz'):
                        src_image_file = os.path.join(subtype_path, file)

                        case_str_image = f"case_{case_id:03d}_0000.nii.gz"
                        dest_image_file = os.path.join(image_dest, case_str_image)
                        shutil.copy(src_image_file, dest_image_file)

                        src_label_file = src_image_file.replace('_0000.nii.gz', '.nii.gz')
                        
                        # Correct the label file before copying
                        corrected_label_file, unique_labels, orig_labels = correct_labels(src_label_file)
                        # print(corrected_label_file)
                        # print(unique_labels)
                        # print(orig_labels)

                        case_str_label = f"case_{case_id:03d}.nii.gz"
                        dest_label_file = os.path.join(label_dest, case_str_label)
                        
                        shutil.copy(corrected_label_file, dest_label_file)
                        
                        class_mapping[case_str_image] = class_id
                        print(f"""
                        
----------------------------------------------------------------------
({case_id}/{total}) 

Source Image: {src_image_file}
Source Label: {src_label_file}
Corrected Label: {corrected_label_file}
Dest Image: {dest_image_file}
Dest Label: {dest_label_file}
Labels: Class {class_id}, Annotated, Unique labels after correction: {unique_labels}
                        
                        """)
                        case_id += 1
                        # Remove the temporary corrected label file
                        os.remove(corrected_label_file)
                        
        return case_id

# Move training files and record class labels
case_id = move_files(source_train, images_tr_dir, labels_tr_dir, class_mapping, 1)
print("\n\n##################\n\n")
case_id = move_files(source_val, images_tr_dir, labels_tr_dir, class_mapping, case_id)
print("\n\n##################\n\n")
case_id = move_files(source_test, images_ts_dir, None, class_mapping, case_id)

# Save the class mapping to a JSON file
with open(os.path.join(target_task_dir, 'class_mapping.json'), 'w') as f:
    json.dump(class_mapping, f)

print("Data restructuring complete and class mapping saved.")
# Out:
# Original unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_416.nii.gz: [0. 1. 2.]
# Corrected unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_416.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (1/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_416_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_416.nii.gz
# Corrected Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_416_corrected.nii.gz
# Dest Image: original_data/Task006_PancreasUHN/imagesTr/case_001_0000.nii.gz
# Dest Label: original_data/Task006_PancreasUHN/labelsTr/case_001.nii.gz
# Labels: Class 2, Annotated, Unique labels after correction: [0. 1. 2.]
#
#
# Original unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_040.nii.gz: [0. 1. 2.]
# Corrected unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_040.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (2/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_040_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_040.nii.gz
# Corrected Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_040_corrected.nii.gz
# Dest Image: original_data/Task006_PancreasUHN/imagesTr/case_002_0000.nii.gz
# Dest Label: original_data/Task006_PancreasUHN/labelsTr/case_002.nii.gz
# Labels: Class 2, Annotated, Unique labels after correction: [0. 1. 2.]
#
#
# Original unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_493.nii.gz: [0. 1. 2.]
# Corrected unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_493.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (3/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_493_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_493.nii.gz
# Corrected Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_493_corrected.nii.gz
# Dest Image: original_data/Task006_PancreasUHN/imagesTr/case_003_0000.nii.gz
# Dest Label: original_data/Task006_PancreasUHN/labelsTr/case_003.nii.gz
# Labels: Class 2, Annotated, Unique labels after correction: [0. 1. 2.]
#
#
# Original unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_321.nii.gz: [0.         1.00001526 2.        ]
# Corrected unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_321.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (4/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_321_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_321.nii.gz
# Corrected Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_321_corrected.nii.gz
# Dest Image: original_data/Task006_PancreasUHN/imagesTr/case_004_0000.nii.gz
# Dest Label: original_data/Task006_PancreasUHN/labelsTr/case_004.nii.gz
# Labels: Class 2, Annotated, Unique labels after correction: [0. 1. 2.]
#
#
# Original unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_002.nii.gz: [0.         1.00001526 2.        ]
# Corrected unique labels in original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_002.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (5/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_002_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2
_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_452.nii.gz: [0. 1. 2.]
# ----------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------
# (51/169)
#
# Source Image: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_452_0000.nii.gz
# Source Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_452.nii.gz
# Corrected Label: original_data/UHN-MedImg3D-ML-quiz/train/subtype2/quiz_2_452_corrected.nii.gz
# Dest Image: original_data/Task006_PancreasUHN/imagesTr/case_051_0000.nii.gz
# Dest Label: original_data/Task006_PancreasUHN/labelsTr/case_051.nii.gz
# Labels: Class 2, Annotated, Unique labels after correction: [0. 1. 2.]
#
#
# ...
# (9/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_141_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_009_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (10/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_068_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_010_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (11/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_351_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_011_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (12/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_353_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_012_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (13/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_524_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_013_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (14/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_155_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_014_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (15/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_369_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_015_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (16/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_097_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_016_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (17/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_161_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_017_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (18/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_367_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_018_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (19/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_267_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_019_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (20/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_424_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_020_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (21/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_269_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_021_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (22/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_053_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_022_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (23/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_162_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_023_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (24/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_095_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_024_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (25/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_135_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_025_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (26/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_409_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_026_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (27/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_152_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_027_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (28/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_238_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_028_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (29/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_429_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_029_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (30/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_092_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_030_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (31/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_261_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_031_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (32/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_069_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_032_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (33/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_388_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_033_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (34/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_275_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_034_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (35/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_378_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_035_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (36/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_280_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_036_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (37/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_417_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_037_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (38/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_101_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_038_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (39/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_376_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_039_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (40/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_521_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_040_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (41/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_229_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_041_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (42/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_504_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_042_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (43/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_129_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_043_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (44/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_422_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_044_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (45/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_266_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_045_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (46/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_405_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_046_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (47/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_425_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_047_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (48/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_428_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_048_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (49/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_226_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_049_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (50/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_228_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_050_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (51/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_349_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_051_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (52/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_233_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_052_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (53/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_408_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_053_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (54/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_048_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_054_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (55/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_052_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_055_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (56/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_371_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_056_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (57/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_047_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_057_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (58/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_130_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_058_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (59/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_357_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_059_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (60/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_520_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_060_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (61/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_146_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_061_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (62/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_263_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_062_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (63/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_257_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_063_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (64/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_347_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_064_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (65/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_144_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_065_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (66/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_108_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_066_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (67/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_157_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_067_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (68/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_270_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_068_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (69/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_137_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_069_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (70/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_271_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_070_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# (71/72) Source Image: original_data/UHN-MedImg3D-ML-quiz/test/quiz_402_0000.nii.gz
#                       Dest Image: original_data/Task006_PancreasUHN/imagesTs/case_071_0000.nii.gz
#                       Labels: No Class, Not Annotated
#
# Data restructuring complete and class mapping saved.

# %%
# import os


# # Directory containing the files
# directory = 'nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTs'
# start_number = 289
# files = sorted(os.listdir(directory))


# for i, filename in enumerate(files):

#     new_filename = f"case_{start_number + i:03d}_0000.nii.gz"
    
#     old_file = os.path.join(directory, filename)
#     new_file = os.path.join(directory, new_filename)
    
#     os.rename(old_file, new_file)

#     print(f'Renamed: {filename} -> {new_filename}')

# %%
import os
import numpy as np
import nibabel as nib

def load_nifti_image(file_path):
    """Load a NIfTI image and return the data as a numpy array."""
    nifti_image = nib.load(file_path)
    return nifti_image.get_fdata()

def collect_unique_labels(labels_dir):
    """Collect and print all unique labels in the dataset."""
    unique_labels = set()
    
    label_files = sorted(os.listdir(labels_dir))
    
    for lbl_file in label_files:
        lbl_path = os.path.join(labels_dir, lbl_file)
        labels = load_nifti_image(lbl_path)
        unique_labels.update(np.unique(labels))
    
    return unique_labels

# %%
# Define the path to the labels directory
pancreas_labels_dir = 'original_data/Task006_PancreasUHN/labelsTr'

# Collect unique labels
pancreas_unique_labels = collect_unique_labels(pancreas_labels_dir)

# Print the unique labels
print(f"Unique labels in the dataset: {sorted(pancreas_unique_labels)}")
# Out:
# Unique labels in the dataset: [0.0, 1.0, 2.0]

# %%
! mv original_data/Task006_PancreasUHN/ nnUNet_raw_data_base/nnUNet_raw_data/

# %%
train_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTs'
test_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTs'

# %%
# remove_suffix(test_dir)

# %%
import os
import json

def create_dataset_json(base_dir, task_name, num_training, num_test):
    
    imagesTr_dir = os.path.join(base_dir, task_name, 'imagesTr')
    labelsTr_dir = os.path.join(base_dir, task_name, 'labelsTr')
    imagesTs_dir = os.path.join(base_dir, task_name, 'imagesTs')

    # Get list of training and test images
    training_images = sorted(os.listdir(imagesTr_dir))
    test_images = sorted(os.listdir(imagesTs_dir))

    # Ensure the number of requested training and test images does not exceed available images
    num_training = min(num_training, len(training_images))
    num_test = min(num_test, len(test_images))

    # Create the dataset dictionary
    dataset = {
        "name": "Pancreas_UHN",
        "description": "Segmentation of pancreatic structures using UHN dataset",
        "tensorImageSize": "3D",
        "reference": "",
        "licence": "",
        "release": "0.0",
        "modality": {
            "0": "CT"
        },
        "labels": {
            "0": "background",
            "1": "pancreas",
            "2": "lesion"
            # Add other structures as needed
        },
        "numTraining": num_training,
        "numTest": num_test,
        "training": [],
        "test": []
    }

    # Populate the training field
    # In the dataset file, no files should have _0000 suffix
    for i in range(num_training):
        dataset['training'].append({
            # "image": f"./imagesTr/{training_images[i]}",
            "image": f"./imagesTr/{training_images[i].replace('_0000.nii.gz', '.nii.gz')}",
            "label": f"./labelsTr/{training_images[i].replace('_0000.nii.gz', '.nii.gz')}"
        })

    # Populate the test field
    for i in range(num_test):
        # dataset['test'].append(f"./imagesTs/{test_images[i]}")
        dataset['test'].append(f"./imagesTs/{test_images[i].replace('_0000.nii.gz', '.nii.gz')}")

    # Save the dataset.json file
    with open(os.path.join(base_dir, task_name, 'dataset.json'), 'w') as f:
        json.dump(dataset, f, indent=4)

# Define the parameters
base_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/'
task_name = 'Task006_PancreasUHN'  # Replace 002 with the actual task number
num_training = 288  # Set the number of training samples
num_test = 72  # Set the number of test samples

# Create the dataset.json file
create_dataset_json(base_dir, task_name, num_training, num_test)
print('Done')
# Out:
# Done

# %%
! nnUNet_plan_and_preprocess -t 06 --verify_dataset_integrity
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# Verifying training set
# checking case case_001
# checking case case_002
# checking case case_003
# checking case case_004
# checking case case_005
# checking case case_006
# checking case case_007
# checking case case_008
# checking case case_009
# checking case case_010
# checking case case_011
# checking case case_012
# checking case case_013
# checking case case_014
# checking case case_015
# the spacing does not match between the images
# (0.814453125, 0.814453125, 0.699999988079071)
# (0.814453125, 0.814453125, 0.70001220703125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_015 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case
does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_196
# the spacing does not match between the images
# (0.6039999723434448, 0.6039999723434448, 0.800000011920929)
# (0.6039999723434448, 0.6039999723434448, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_196 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_197
# checking case case_198
# checking case case_199
# the spacing does not match between the images
# (0.6499999761581421, 0.6499999761581421, 0.800000011920929)
# (0.6499999761581421, 0.6499999761581421, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_199 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_200
# checking case case_201
# the spacing does not match between the images
# (0.7170000076293945, 0.7170000076293945, 0.800000011920929)
# (0.7170000076293945, 0.7170000076293945, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_201 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_202
# checking case case_203
# checking case case_204
# checking case case_205
# checking case case_206
# the spacing does not match between the images
# (0.7820000052452087, 0.7820000052452087, 0.800000011920929)
# (0.7820000052452087, 0.7820000052452087, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_206 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_207
# the spacing does not match between the images
# (0.6890000104904175, 0.6890000104904175, 2.4000000953674316)
# (0.6890000104904175, 0.6890000104904175, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_207 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_208
# checking case case_209
# checking case case_210
# checking case case_211
# checking case case_212
# the spacing does not match between the images
# (0.7820000052452087, 0.7820000052452087, 0.800000011920929)
# (0.7820000052452087, 0.7820000052452087, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_212 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_213
# checking case case_214
# checking case case_215
# checking case case_216
# checking case case_217
# checking case case_218
# checking case case_219
# checking case case_220
# the spacing does not match between the images
# (0.6179999709129333, 0.6179999709129333, 0.800000011920929)
# (0.6179999709129333, 0.6179999709129333, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_220 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_221
# checking case case_222
# checking case case_223
# checking case case_224
# checking case case_225
# checking case case_226
# checking case case_227
# the spacing does not match between the images
# (0.3910059928894043, 0.3910059928894043, 2.4000000953674316)
# (0.3910059928894043, 0.3910059928894043, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_227 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_228
# the spacing does not match between the images
# (0.8920000195503235, 0.8920000195503235, 2.4000000953674316)
# (0.8920000195503235, 0.8920000195503235, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_228 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_229
# checking case case_230
# checking case case_231
# the spacing does not match between the images
# (0.7409999966621399, 0.7409999966621399, 2.4000000953674316)
# (0.7409999966621399, 0.7409999966621399, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_231 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_232
# checking case case_233
# checking case case_234
# checking case case_235
# the spacing does not match between the images
# (0.3910059928894043, 0.3910059928894043, 0.7543209791183472)
# (0.3910059928894043, 0.3910059928894043, 0.5)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_235 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_236
# the spacing does not match between the images
# (0.781000018119812, 0.781000018119812, 0.800000011920929)
# (0.781000018119812, 0.781000018119812, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_236 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_237
# the spacing does not match between the images
# (0.6069999933242798, 0.6069999933242798, 2.4000000953674316)
# (0.6069999933242798, 0.6069999933242798, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_237 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_238
# checking case case_239
# checking case case_240
# checking case case_241
# checking case case_242
# checking case case_243
# the spacing does not match between the images
# (0.3910059928894043, 0.3910059928894043, 8.0)
# (0.3910059928894043, 0.3910059928894043, 4.79998779296875)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_243 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_244
# checking case case_245
# checking case case_246
# checking case case_247
# checking case case_248
# checking case case_249
# the spacing does not match between the images
# (0.8769999742507935, 0.8769999742507935, 0.800000011920929)
# (0.8769999742507935, 0.8769999742507935, 0.800048828125)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_249 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_250
# checking case case_251
# checking case case_252
# checking case case_253
# checking case case_254
# checking case case_255
# checking case case_256
# checking case case_257
# checking case case_258
# checking case case_259
# checking case case_260
# checking case case_261
# checking case case_262
# checking case case_263
# checking case case_264
# checking case case_265
# checking case case_266
# checking case case_267
# checking case case_268
# checking case case_269
# checking case case_270
# checking case case_271
# checking case case_272
# checking case case_273
# checking case case_274
# checking case case_275
# checking case case_276
# checking case case_277
# checking case case_278
# checking case case_279
# checking case case_280
# checking case case_281
# checking case case_282
# checking case case_283
# checking case case_284
# checking case case_285
# the spacing does not match between the images
# (0.39005300402641296, 0.39005300402641296, 2.4000000953674316)
# (0.39005300402641296, 0.39005300402641296, 2.4000244140625)
# The geometry of the image /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task006_PancreasUHN/imagesTr/case_285 does not match the geometry of the label file. The pixel arrays will not be aligned and nnU-Net cannot use this data. Please make sure your image modalities are coregistered and have the same geometry as the label
# checking case case_286
# checking case case_287
# checking case case_288
# Verifying label values
# Expected label values are [0, 1, 2]
# Labels OK
# Verifying test set
# Traceback (most recent call last):
#   File "/home/alif/.local/bin/nnUNet_plan_and_preprocess", line 33, in <module>
#     sys.exit(load_entry_point('nnunet', 'console_scripts', 'nnUNet_plan_and_preprocess')())
#   File "/scratch/alif/nnUNet/nnunet/experiment_planning/nnUNet_plan_and_preprocess.py", line 105, in main
#     verify_dataset_integrity(join(nnUNet_raw_data, task_name))
#   File "/scratch/alif/nnUNet/nnunet/preprocessing/sanity_checks.py", line 230, in verify_dataset_integrity
#     raise Warning("GEOMETRY MISMATCH FOUND! CHECK THE TEXT OUTPUT! This does not cause an error at this point  but you should definitely check whether your geometries are alright!")
# Warning: GEOMETRY MISMATCH FOUND! CHECK THE TEXT OUTPUT! This does not cause an error at this point  but you should definitely check whether your geometries are alright!

# %%
! nnUNet_plan_and_preprocess -t 06 -tf 14 -tl 14
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# case_001
# case_013
# case_007
# case_019
# case_025
# case_031
# case_037
# case_043
# case_049
# case_055
# case_061
# case_067
# case_073
# case_079
# before crop: (1, 68, 143, 176) after crop: (1, 68, 143, 176) spacing: [1.5        0.62890625 0.62890625]
#
# before crop: (1, 73, 97, 161) after crop: (1, 73, 97, 161) spacing: [1.5        0.71679688 0.71679688]
#
# before crop: (1, 117, 149, 204) after crop: (1, 117, 149, 204) spacing: [1.        0.7265625 0.7265625]
#
# before crop: (1, 45, 157, 155) after crop: (1, 45, 157, 155) spacing: [3.         0.69921875 0.69921875]
#
# case_008
# before crop: (1, 50, 124, 201) after crop: (1, 50, 124, 201) spacing: [3.      0.78125 0.78125]
#
# case_068
# before crop: (1, 85, 142, 218) after crop: (1, 85, 142, 218) spacing: [1.5       0.6796875 0.6796875]
#
# case_080
# case_038
# before crop: (1, 56, 102, 201) after crop: (1, 56, 102, 201) spacing: [2.         0.76171875 0.76171875]
#
# before crop: (1, 85, 130, 189) after crop: (1, 85, 130, 189) spacing: [1.5       0.7421875 0.7421875]
#
# before crop: (1, 79, 124, 174) after crop: (1, 79, 124, 174) spacing: [1.5        0.68359375 0.68359375]
#
# before crop: (1, 49, 130, 166) after crop: (1, 49, 130, 166) spacing: [3.         0.75195312 0.75195312]
#
# before crop: (1, 98, 90, 209) after crop: (1, 98, 90, 209) spacing: [1.       0.828125 0.828125]
#
# before crop: (1, 79, 153, 245) after crop: (1, 79, 153, 245) spacing: [1.5       0.5390625 0.5390625]
#
# case_056
# case_044
# case_026
# before crop: (1, 106, 149, 207) after crop: (1, 106, 149, 207) spacing: [1.         0.60546875 0.60546875]
#
# case_014
# case_074
# before crop: (1, 42, 87, 118) after crop: (1, 42, 87, 118) spacing: [3.         0.72265625 0.72265625]
#
# case_075
# before crop: (1, 74, 116, 221) after crop: (1, 74, 116, 221) spacing: [1.5       0.6953125 0.6953125]
#
# case_032
# before crop: (1, 66, 97, 188) after crop: (1, 66, 97, 188) spacing: [2.      0.78125 0.78125]
#
# before crop: (1, 94, 106, 189) after crop: (1, 94, 106, 189) spacing: [1.19995117 0.61914062 0.61914062]
#
# case_009
# case_076
# before crop: (1, 56, 140, 190) after crop: (1, 56, 140, 190) spacing: [3.         0.75195312 0.75195312]
#
# before crop: (1, 76, 115, 160) after crop: (1, 76, 115, 160) spacing: [1.5        0.81835938 0.81835938]
#
# case_069
# case_020
# case_033
# case_015
# before crop: (1, 92, 111, 206) after crop: (1, 92, 111, 206) spacing: [1.        0.7734375 0.7734375]
#
# before crop: (1, 129, 111, 135) after crop: (1, 129, 111, 135) spacing: [0.69999999 0.81445312 0.81445312]
#
# case_010
# case_021
# before crop: (1, 59, 108, 127) after crop: (1, 59, 108, 127) spacing: [2.       0.703125 0.703125]
#
# before crop: (1, 159, 119, 196) after crop: (1, 159, 119, 196) spacing: [0.59997559 0.7890625  0.7890625 ]
#
# before crop: (1, 61, 127, 139) after crop: (1, 61, 127, 139) spacing: [2.         0.70703125 0.70703125]
#
# before crop: (1, 49, 102, 167) after crop: (1, 49, 102, 167) spacing: [3.        0.7734375 0.7734375]
#
# before crop: (1, 52, 119, 220) after crop: (1, 52, 119, 220) spacing: [3.      0.78125 0.78125]
#
# case_077
# before crop: (1, 106, 136, 200) after crop: (1, 106, 136, 200) spacing: [1.20001221 0.68359375 0.68359375]
#
# before crop: (1, 152, 127, 174) after crop: (1, 152, 127, 174) spacing: [0.59997559 0.73828125 0.73828125]
#
# before crop: (1, 218, 215, 221) after crop: (1, 218, 215, 221) spacing: [0.70001221 0.69921875 0.69921875]
#
# case_039
# before crop: (1, 63, 85, 142) after crop: (1, 63, 85, 142) spacing: [1.20001221 0.64257812 0.64257812]
#
# before crop: (1, 57, 141, 196) after crop: (1, 57, 141, 196) spacing: [3.         0.72460938 0.72460938]
#
# case_027
# before crop: (1, 117, 131, 162) after crop: (1, 117, 131, 162) spacing: [0.59999084 0.84375    0.84375   ]
#
# case_016
# case_078
# case_081
# case_022
# case_062
# case_002
# case_057
# before crop: (1, 86, 92, 198) after crop: (1, 86, 92, 198) spacing: [1.5       0.7421875 0.7421875]
#
# case_040
# before crop: (1, 29, 120, 147) after crop: (1, 29, 120, 147) spacing: [3.         0.71484375 0.71484375]
#
# case_050
# case_045
# case_063
# before crop: (1, 103, 119, 220) after crop: (1, 103, 119, 220) spacing: [1.         0.75390625 0.75390625]
#
# before crop: (1, 45, 142, 210) after crop: (1, 45, 142, 210) spacing: [3.         0.69140625 0.69140625]
#
# before crop: (1, 48, 108, 167) after crop: (1, 48, 108, 167) spacing: [3.        0.6953125 0.6953125]
#
# case_034
# before crop: (1, 66, 141, 162) after crop: (1, 66, 141, 162) spacing: [1.5        0.68359375 0.68359375]
#
# case_051
# before crop: (1, 71, 104, 179) after crop: (1, 71, 104, 179) spacing: [1.5     0.84375 0.84375]
#
# case_046
# before crop: (1, 83, 137, 204) after crop: (1, 83, 137, 204) spacing: [1.5        0.70507812 0.70507812]
#
# case_052
# before crop: (1, 48, 108, 169) after crop: (1, 48, 108, 169) spacing: [3.         0.77539062 0.77539062]
#
# case_064
# before crop: (1, 178, 111, 155) after crop: (1, 178, 111, 155) spacing: [0.59997559 0.80859375 0.80859375]
#
# case_070
# before crop: (1, 45, 120, 137) after crop: (1, 45, 120, 137) spacing: [3.         0.88476562 0.88476562]
#
# before crop: (1, 55, 134, 176) after crop: (1, 55, 134, 176) spacing: [2.         0.72070312 0.72070312]
#
# before crop: (1, 43, 87, 166) after crop: (1, 43, 87, 166) spacing: [3.         0.81054688 0.81054688]
#
# case_065
# case_071
# case_053
# before crop: (1, 87, 156, 237) after crop: (1, 87, 156, 237) spacing: [1.5     0.71875 0.71875]
#
# case_011
# before crop: (1, 71, 138, 195) after crop: (1, 71, 138, 195) spacing: [2.         0.76757812 0.76757812]
#
# before crop: (1, 46, 125, 171) after crop: (1, 46, 125, 171) spacing: [3.         0.73046875 0.73046875]
#
# before crop: (1, 70, 158, 167) after crop: (1, 70, 158, 167) spacing: [1.5        0.90429688 0.90429688]
#
# before crop: (1, 67, 107, 147) after crop: (1, 67, 107, 147) spacing: [1.5        0.69335938 0.69335938]
#
# before crop: (1, 49, 109, 161) after crop: (1, 49, 109, 161) spacing: [3.      0.78125 0.78125]
#
# before crop: (1, 161, 161, 241) after crop: (1, 161, 161, 241) spacing: [0.6000061  0.62695312 0.62695312]
#
# before crop: (1, 52, 117, 171) after crop: (1, 52, 117, 171) spacing: [2.      0.78125 0.78125]
#
# case_035
# case_047
# case_028
# case_023
# before crop: (1, 48, 95, 153) after crop: (1, 48, 95, 153) spacing: [3.         0.80859375 0.80859375]
#
# case_082
# before crop: (1, 128, 125, 195) after crop: (1, 128, 125, 195) spacing: [1.         0.71399999 0.71399999]
#
# case_085
# case_024
# case_003
# case_041
# case_017
# case_029
# before crop: (1, 62, 119, 250) after crop: (1, 62, 119, 250) spacing: [1.5    0.6875 0.6875]
#
# before crop: (1, 47, 86, 127) after crop: (1, 47, 86, 127) spacing: [3.     0.9375 0.9375]
#
# before crop: (1, 60, 99, 173) after crop: (1, 60, 99, 173) spacing: [2.         0.68359375 0.68359375]
#
# case_066
# before crop: (1, 78, 80, 93) after crop: (1, 78, 80, 93) spacing: [1.5    0.9375 0.9375]
#
# case_058
# before crop: (1, 151, 154, 206) after crop: (1, 151, 154, 206) spacing: [0.59999084 0.68164062 0.68164062]
#
# before crop: (1, 60, 112, 186) after crop: (1, 60, 112, 186) spacing: [2.         0.76953125 0.76953125]
#
# case_036
# before crop: (1, 50, 117, 176) after crop: (1, 50, 117, 176) spacing: [3.         0.87109375 0.87109375]
#
# before crop: (1, 52, 127, 206) after crop: (1, 52, 127, 206) spacing: [3.       0.765625 0.765625]
#
# case_054
# before crop: (1, 96, 113, 165) after crop: (1, 96, 113, 165) spacing: [1.5        0.68945312 0.68945312]
#
# before crop: (1, 78, 82, 135) after crop: (1, 78, 82, 135) spacing: [1.5       0.7421875 0.7421875]
#
# case_091
# case_030
# before crop: (1, 76, 134, 221) after crop: (1, 76, 134, 221) spacing: [1.5       0.8046875 0.8046875]
#
# case_018
# case_097
# case_072
# before crop: (1, 159, 117, 190) after crop: (1, 159, 117, 190) spacing: [0.59997559 0.67578125 0.67578125]
#
# before crop: (1, 45, 122, 188) after crop: (1, 45, 122, 188) spacing: [3.   0.75 0.75]
#
# case_004
# before crop: (1, 53, 88, 178) after crop: (1, 53, 88, 178) spacing: [1.5        0.66601562 0.66601562]
#
# case_103
# case_059
# before crop: (1, 21, 112, 134) after crop: (1, 21, 112, 134) spacing: [3.         0.71484375 0.71484375]
#
# case_012
# before crop: (1, 66, 106, 163) after crop: (1, 66, 106, 163) spacing: [1.5       0.6640625 0.6640625]
#
# before crop: (1, 151, 105, 167) after crop: (1, 151, 105, 167) spacing: [0.80000001 0.76367188 0.76367188]
#
# case_109
# case_115
# before crop: (1, 63, 114, 145) after crop: (1, 63, 114, 145) spacing: [1.5        0.69921875 0.69921875]
#
# case_121
# before crop: (1, 81, 126, 194) after crop: (1, 81, 126, 194) spacing: [1.5        0.76953125 0.76953125]
#
# before crop: (1, 62, 135, 199) after crop: (1, 62, 135, 199) spacing: [2.         0.62109375 0.62109375]
#
# case_127
# before crop: (1, 122, 129, 177) after crop: (1, 122, 129, 177) spacing: [1.        0.7578125 0.7578125]
#
# before crop: (1, 59, 132, 179) after crop: (1, 59, 132, 179) spacing: [2.         0.68164062 0.68164062]
#
# case_083
# before crop: (1, 34, 75, 175) after crop: (1, 34, 75, 175) spacing: [5.      0.78125 0.78125]
#
# case_122
# before crop: (1, 48, 166, 213) after crop: (1, 48, 166, 213) spacing: [3.         0.64453125 0.64453125]
#
# case_048
# case_042
# before crop: (1, 49, 140, 217) after crop: (1, 49, 140, 217) spacing: [3.        0.7265625 0.7265625]
#
# case_116
# before crop: (1, 37, 96, 154) after crop: (1, 37, 96, 154) spacing: [3.         0.74414062 0.74414062]
#
# case_104
# before crop: (1, 38, 119, 208) after crop: (1, 38, 119, 208) spacing: [5.         0.68359375 0.68359375]
#
# case_005
# case_084
# case_086
# before crop: (1, 51, 136, 178) after crop: (1, 51, 136, 178) spacing: [3.        0.7421875 0.7421875]
#
# case_098
# case_105
# case_128
# before crop: (1, 100, 103, 173) after crop: (1, 100, 103, 173) spacing: [1.         0.60742188 0.60742188]
#
# before crop: (1, 81, 143, 190) after crop: (1, 81, 143, 190) spacing: [1.5        0.74804688 0.74804688]
#
# before crop: (1, 55, 88, 146) after crop: (1, 55, 88, 146) spacing: [2.       0.859375 0.859375]
#
# before crop: (1, 53, 125, 213) after crop: (1, 53, 125, 213) spacing: [3.         0.68359375 0.68359375]
#
# before crop: (1, 111, 157, 263) after crop: (1, 111, 157, 263) spacing: [1.5        0.80273438 0.80273438]
#
# before crop: (1, 45, 87, 126) after crop: (1, 45, 87, 126) spacing: [3.       0.703125 0.703125]
#
# before crop: (1, 98, 86, 202) after crop: (1, 98, 86, 202) spacing: [1.        0.7265625 0.7265625]
#
# before crop: (1, 89, 157, 174) after crop: (1, 89, 157, 174) spacing: [1.        0.6953125 0.6953125]
#
# before crop: (1, 53, 106, 167) after crop: (1, 53, 106, 167) spacing: [1.99999988 0.7265625  0.7265625 ]
#
# case_123
# before crop: (1, 80, 122, 187) after crop: (1, 80, 122, 187) spacing: [1.5       0.7421875 0.7421875]
#
# case_133
# before crop: (1, 54, 114, 196) after crop: (1, 54, 114, 196) spacing: [2.         0.74609375 0.74609375]
#
# case_129
# case_110
# before crop: (1, 60, 160, 222) after crop: (1, 60, 160, 222) spacing: [2.         0.78515625 0.78515625]
#
# case_139
# case_099
# case_092
# case_087
# before crop: (1, 61, 117, 194) after crop: (1, 61, 117, 194) spacing: [3.         0.87695312 0.87695312]
#
# before crop: (1, 39, 153, 189) after crop: (1, 39, 153, 189) spacing: [3.         0.59179688 0.59179688]
#
# case_145
# case_151
# case_134
# before crop: (1, 72, 100, 184) after crop: (1, 72, 100, 184) spacing: [1.        0.6796875 0.6796875]
#
# case_124
# before crop: (1, 103, 118, 192) after crop: (1, 103, 118, 192) spacing: [1.         0.68359375 0.68359375]
#
# before crop: (1, 35, 138, 201) after crop: (1, 35, 138, 201) spacing: [5.         0.65820312 0.65820312]
#
# before crop: (1, 35, 138, 176) after crop: (1, 35, 138, 176) spacing: [5.        0.6953125 0.6953125]
#
# case_130
# case_125
# before crop: (1, 37, 83, 168) after crop: (1, 37, 83, 168) spacing: [3.         0.72265625 0.72265625]
#
# case_126
# case_100
# before crop: (1, 34, 128, 181) after crop: (1, 34, 128, 181) spacing: [4.99999952 0.76171875 0.76171875]
#
# before crop: (1, 98, 121, 190) after crop: (1, 98, 121, 190) spacing: [1.         0.73046875 0.73046875]
#
# before crop: (1, 49, 96, 208) after crop: (1, 49, 96, 208) spacing: [3.         0.68945312 0.68945312]
#
# before crop: (1, 188, 117, 190) after crop: (1, 188, 117, 190) spacing: [0.44998169 0.68359375 0.68359375]
#
# case_157
# case_117
# case_146
# before crop: (1, 62, 109, 158) after crop: (1, 62, 109, 158) spacing: [2.         0.78320312 0.78320312]
#
# case_111
# before crop: (1, 98, 142, 180) after crop: (1, 98, 142, 180) spacing: [1.5        0.68359375 0.68359375]
#
# case_060
# before crop: (1, 223, 147, 196) after crop: (1, 223, 147, 196) spacing: [0.45001221 0.72265625 0.72265625]
#
# case_131
# case_006
# case_106
# case_135
# before crop: (1, 89, 72, 155) after crop: (1, 89, 72, 155) spacing: [1.         0.87695312 0.87695312]
#
# before crop: (1, 52, 108, 181) after crop: (1, 52, 108, 181) spacing: [3.         0.64257812 0.64257812]
#
# before crop: (1, 98, 109, 173) after crop: (1, 98, 109, 173) spacing: [0.69999999 0.71875    0.71875   ]
#
# before crop: (1, 70, 130, 178) after crop: (1, 70, 130, 178) spacing: [2.         0.75195312 0.75195312]
#
# before crop: (1, 36, 90, 154) after crop: (1, 36, 90, 154) spacing: [5.      0.78125 0.78125]
#
# before crop: (1, 114, 102, 232) after crop: (1, 114, 102, 232) spacing: [1.         0.77148438 0.77148438]
#
# case_112
# case_147
# case_136
# before crop: (1, 50, 151, 176) after crop: (1, 50, 151, 176) spacing: [3.        0.6640625 0.6640625]
#
# before crop: (1, 120, 120, 223) after crop: (1, 120, 120, 223) spacing: [0.80000001 0.73828125 0.73828125]
#
# before crop: (1, 50, 140, 225) after crop: (1, 50, 140, 225) spacing: [3.         0.74023438 0.74023438]
#
# case_163
# case_169
# before crop: (1, 110, 68, 156) after crop: (1, 110, 68, 156) spacing: [1.      0.96875 0.96875]
#
# before crop: (1, 67, 123, 150) after crop: (1, 67, 123, 150) spacing: [2.         0.69921875 0.69921875]
#
# case_107
# case_170
# before crop: (1, 47, 85, 144) after crop: (1, 47, 85, 144) spacing: [4.         0.84570312 0.84570312]
#
# case_171
# before crop: (1, 103, 123, 168) after crop: (1, 103, 123, 168) spacing: [1.        0.7265625 0.7265625]
#
# before crop: (1, 47, 119, 176) after crop: (1, 47, 119, 176) spacing: [3.         0.68359375 0.68359375]
#
# case_172
# case_101
# case_158
# before crop: (1, 48, 90, 176) after crop: (1, 48, 90, 176) spacing: [3.         0.76367188 0.76367188]
#
# case_108
# case_132
# case_113
# case_164
# before crop: (1, 86, 92, 164) after crop: (1, 86, 92, 164) spacing: [1.         0.73046875 0.73046875]
#
# before crop: (1, 83, 166, 248) after crop: (1, 83, 166, 248) spacing: [1.       0.546875 0.546875]
#
# case_159
# before crop: (1, 60, 117, 145) after crop: (1, 60, 117, 145) spacing: [2.         0.90429688 0.90429688]
#
# case_160
# case_102
# before crop: (1, 43, 91, 151) after crop: (1, 43, 91, 151) spacing: [3.         0.93945312 0.93945312]
#
# before crop: (1, 47, 97, 184) after crop: (1, 47, 97, 184) spacing: [3.         0.79101562 0.79101562]
#
# before crop: (1, 47, 108, 168) after crop: (1, 47, 108, 168) spacing: [3.        0.7578125 0.7578125]
#
# before crop: (1, 53, 128, 222) after crop: (1, 53, 128, 222) spacing: [2.         0.65820312 0.65820312]
#
# case_152
# before crop: (1, 62, 124, 159) after crop: (1, 62, 124, 159) spacing: [2.         0.65429688 0.65429688]
#
# case_093
# case_175
# case_088
# before crop: (1, 42, 120, 173) after crop: (1, 42, 120, 173) spacing: [3.        0.6640625 0.6640625]
#
# case_140
# case_181
# before crop: (1, 29, 139, 165) after crop: (1, 29, 139, 165) spacing: [5.         0.77929688 0.77929688]
#
# before crop: (1, 48, 109, 209) after crop: (1, 48, 109, 209) spacing: [3.         0.73046875 0.73046875]
#
# before crop: (1, 126, 108, 173) after crop: (1, 126, 108, 173) spacing: [0.80000001 0.7109375  0.7109375 ]
#
# case_118
# case_137
# before crop: (1, 244, 142, 187) after crop: (1, 244, 142, 187) spacing: [0.44995117 0.671875   0.671875  ]
#
# before crop: (1, 57, 116, 203) after crop: (1, 57, 116, 203) spacing: [2.         0.68164062 0.68164062]
#
# case_148
# case_089
# before crop: (1, 63, 89, 160) after crop: (1, 63, 89, 160) spacing: [2.         0.87109375 0.87109375]
#
# case_141
# case_138
# before crop: (1, 62, 188, 194) after crop: (1, 62, 188, 194) spacing: [2.       0.703125 0.703125]
#
# before crop: (1, 97, 121, 159) after crop: (1, 97, 121, 159) spacing: [1.         0.69140625 0.69140625]
#
# before crop: (1, 79, 103, 129) after crop: (1, 79, 103, 129) spacing: [1.        0.7890625 0.7890625]
#
# case_149
# before crop: (1, 80, 128, 167) after crop: (1, 80, 128, 167) spacing: [1.         0.64648438 0.64648438]
#
# before crop: (1, 53, 140, 170) after crop: (1, 53, 140, 170) spacing: [3.         0.73828125 0.73828125]
#
# before crop: (1, 34, 121, 190) after crop: (1, 34, 121, 190) spacing: [5.00000048 0.75390625 0.75390625]
#
# before crop: (1, 79, 133, 138) after crop: (1, 79, 133, 138) spacing: [1.00001597 0.73242188 0.73242188]
#
# before crop: (1, 57, 136, 216) after crop: (1, 57, 136, 216) spacing: [2.         0.63867188 0.63867188]
#
# before crop: (1, 61, 90, 160) after crop: (1, 61, 90, 160) spacing: [2.         0.74804688 0.74804688]
#
# before crop: (1, 103, 132, 171) after crop: (1, 103, 132, 171) spacing: [1.      0.78125 0.78125]
#
# case_176
# case_150
# before crop: (1, 48, 91, 187) after crop: (1, 48, 91, 187) spacing: [3.         0.71484375 0.71484375]
#
# case_182
# case_187
# case_153
# before crop: (1, 131, 109, 128) after crop: (1, 131, 109, 128) spacing: [0.80000001 0.87890625 0.87890625]
#
# case_119
# case_173
# before crop: (1, 34, 149, 184) after crop: (1, 34, 149, 184) spacing: [5.      0.78125 0.78125]
#
# before crop: (1, 101, 106, 196) after crop: (1, 101, 106, 196) spacing: [1.         0.76953125 0.76953125]
#
# case_142
# case_165
# case_094
# case_193
# case_090
# case_114
# case_161
# before crop: (1, 95, 137, 199) after crop: (1, 95, 137, 199) spacing: [1.00000012 0.67578125 0.67578125]
#
# before crop: (1, 36, 101, 173) after crop: (1, 36, 101, 173) spacing: [5.      0.78125 0.78125]
#
# before crop: (1, 102, 152, 141) after crop: (1, 102, 152, 141) spacing: [1.         0.72070312 0.72070312]
#
# before crop: (1, 55, 116, 207) after crop: (1, 55, 116, 207) spacing: [3.         0.79296875 0.79296875]
#
# case_199
# before crop: (1, 103, 109, 159) after crop: (1, 103, 109, 159) spacing: [0.80102539 0.78100002 0.78100002]
#
# before crop: (1, 57, 86, 175) after crop: (1, 57, 86, 175) spacing: [2.         0.74804688 0.74804688]
#
# before crop: (1, 234, 96, 171) after crop: (1, 234, 96, 171) spacing: [0.44998169 0.84375    0.84375   ]
#
# before crop: (1, 108, 130, 191) after crop: (1, 108, 130, 191) spacing: [0.80000001 0.64999998 0.64999998]
#
# case_162
# before crop: (1, 64, 107, 166) after crop: (1, 64, 107, 166) spacing: [2.         0.69726562 0.69726562]
#
# before crop: (1, 109, 123, 172) after crop: (1, 109, 123, 172) spacing: [1.         0.83007812 0.83007812]
#
# before crop: (1, 38, 136, 210) after crop: (1, 38, 136, 210) spacing: [5.         0.68359375 0.68359375]
#
# case_194
# case_143
# before crop: (1, 50, 114, 170) after crop: (1, 50, 114, 170) spacing: [3.        0.7265625 0.7265625]
#
# before crop: (1, 111, 158, 184) after crop: (1, 111, 158, 184) spacing: [1.         0.77734375 0.77734375]
#
# case_166
# before crop: (1, 80, 144, 170) after crop: (1, 80, 144, 170) spacing: [1.    0.625 0.625]
#
# case_205
# case_183
# case_211
# before crop: (1, 39, 110, 192) after crop: (1, 39, 110, 192) spacing: [4.         0.68359375 0.68359375]
#
# case_200
# case_120
# case_188
# case_095
# before crop: (1, 105, 116, 203) after crop: (1, 105, 116, 203) spacing: [1.         0.68359375 0.68359375]
#
# case_195
# before crop: (1, 93, 120, 190) after crop: (1, 93, 120, 190) spacing: [1.        0.7265625 0.7265625]
#
# case_174
# before crop: (1, 56, 116, 169) after crop: (1, 56, 116, 169) spacing: [2.         0.60546875 0.60546875]
#
# before crop: (1, 58, 146, 116) after crop: (1, 58, 146, 116) spacing: [2.4000001 0.782013  0.782013 ]
#
# before crop: (1, 48, 109, 165) after crop: (1, 48, 109, 165) spacing: [3.         0.86523438 0.86523438]
#
# case_196
# case_177
# case_154
# before crop: (1, 98, 120, 135) after crop: (1, 98, 120, 135) spacing: [1.         0.63671875 0.63671875]
#
# before crop: (1, 61, 137, 194) after crop: (1, 61, 137, 194) spacing: [2.         0.68736303 0.68736303]
#
# before crop: (1, 37, 118, 181) after crop: (1, 37, 118, 181) spacing: [5.         0.73828125 0.73828125]
#
# case_217
# case_223
# before crop: (1, 68, 137, 148) after crop: (1, 68, 137, 148) spacing: [2.         0.72460938 0.72460938]
#
# case_189
# before crop: (1, 62, 144, 205) after crop: (1, 62, 144, 205) spacing: [2.         0.74414062 0.74414062]
#
# case_229
# before crop: (1, 69, 89, 157) after crop: (1, 69, 89, 157) spacing: [2.         0.87109375 0.87109375]
#
# case_190
# case_178
# case_184
# before crop: (1, 81, 160, 243) after crop: (1, 81, 160, 243) spacing: [1.         0.63999999 0.63999999]
#
# before crop: (1, 99, 95, 203) after crop: (1, 99, 95, 203) spacing: [1.         0.68359375 0.68359375]
#
# case_155
# case_201
# before crop: (1, 123, 124, 196) after crop: (1, 123, 124, 196) spacing: [0.80000001 0.71700001 0.71700001]
#
# case_167
# case_202
# before crop: (1, 45, 77, 140) after crop: (1, 45, 77, 140) spacing: [3.         0.97600001 0.97600001]
#
# before crop: (1, 40, 116, 155) after crop: (1, 40, 116, 155) spacing: [4.         0.97600001 0.97600001]
#
# case_185
# before crop: (1, 57, 112, 209) after crop: (1, 57, 112, 209) spacing: [2.         0.63867188 0.63867188]
#
# case_212
# case_206
# before crop: (1, 116, 95, 154) after crop: (1, 116, 95, 154) spacing: [0.80102539 0.78200001 0.78200001]
#
# before crop: (1, 109, 163, 205) after crop: (1, 109, 163, 205) spacing: [1.         0.68359375 0.68359375]
#
# before crop: (1, 71, 103, 192) after crop: (1, 71, 103, 192) spacing: [2.         0.62695312 0.62695312]
#
# before crop: (1, 105, 130, 183) after crop: (1, 105, 130, 183) spacing: [0.80000001 0.78200001 0.78200001]
#
# case_144
# before crop: (1, 114, 127, 178) after crop: (1, 114, 127, 178) spacing: [1.         0.78200001 0.78200001]
#
# before crop: (1, 97, 88, 180) after crop: (1, 97, 88, 180) spacing: [1.    0.801 0.801]
#
# before crop: (1, 96, 89, 162) after crop: (1, 96, 89, 162) spacing: [1.         0.65039062 0.65039062]
#
# case_168
# case_203
# case_235
# before crop: (1, 63, 136, 224) after crop: (1, 63, 136, 224) spacing: [2.         0.80078125 0.80078125]
#
# before crop: (1, 42, 209, 238) after crop: (1, 42, 209, 238) spacing: [3.       0.351906 0.351906]
#
# case_204
# before crop: (1, 104, 130, 206) after crop: (1, 104, 130, 206) spacing: [1.    0.866 0.866]
#
# case_191
# case_218
# before crop: (1, 142, 146, 180) after crop: (1, 142, 146, 180) spacing: [0.80000001 0.60399997 0.60399997]
#
# before crop: (1, 96, 125, 205) after crop: (1, 96, 125, 205) spacing: [1.         0.78899997 0.78899997]
#
# case_241
# before crop: (1, 65, 137, 189) after crop: (1, 65, 137, 189) spacing: [2.         0.68164062 0.68164062]
#
# case_213
# before crop: (1, 112, 117, 190) after crop: (1, 112, 117, 190) spacing: [0.80000001 0.78200001 0.78200001]
#
# case_224
# case_096
# case_207
# before crop: (1, 121, 149, 129) after crop: (1, 121, 149, 129) spacing: [1.         0.77929688 0.77929688]
#
# case_197
# case_192
# case_186
# before crop: (1, 109, 126, 178) after crop: (1, 109, 126, 178) spacing: [1.         0.72899997 0.72899997]
#
# before crop: (1, 49, 95, 187) after crop: (1, 49, 95, 187) spacing: [3.         0.87699997 0.87699997]
#
# before crop: (1, 45, 140, 200) after crop: (1, 45, 140, 200) spacing: [3.         0.78200001 0.78200001]
#
# case_247
# case_253
# before crop: (1, 172, 185, 292) after crop: (1, 172, 185, 292) spacing: [0.5     0.44632 0.44632]
#
# case_230
# before crop: (1, 106, 161, 239) after crop: (1, 106, 161, 239) spacing: [1.         0.62695312 0.62695312]
#
# before crop: (1, 112, 121, 201) after crop: (1, 112, 121, 201) spacing: [1.       0.734375 0.734375]
#
# before crop: (1, 87, 124, 179) after crop: (1, 87, 124, 179) spacing: [1.5       0.8984375 0.8984375]
#
# case_179
# before crop: (1, 49, 151, 186) after crop: (1, 49, 151, 186) spacing: [3.00000024 0.65625    0.65625   ]
#
# case_214
# case_225
# case_254
# case_156
# case_259
# before crop: (1, 50, 104, 147) after crop: (1, 50, 104, 147) spacing: [3.         0.80859375 0.80859375]
#
# before crop: (1, 109, 124, 204) after crop: (1, 109, 124, 204) spacing: [1.         0.78200001 0.78200001]
#
# before crop: (1, 101, 258, 459) after crop: (1, 101, 258, 459) spacing: [0.75432098 0.39100599 0.39100599]
#
# before crop: (1, 44, 84, 175) after crop: (1, 44, 84, 175) spacing: [3.         0.95300001 0.95300001]
#
# before crop: (1, 92, 115, 152) after crop: (1, 92, 115, 152) spacing: [1.         0.75300002 0.75300002]
#
# before crop: (1, 52, 270, 336) after crop: (1, 52, 270, 336) spacing: [2.4000001  0.33855399 0.33855399]
#
# before crop: (1, 50, 82, 163) after crop: (1, 50, 82, 163) spacing: [2.4000001  0.78200001 0.78200001]
#
# before crop: (1, 102, 88, 164) after crop: (1, 102, 88, 164) spacing: [1.         0.76899999 0.76899999]
#
# before crop: (1, 100, 95, 189) after crop: (1, 100, 95, 189) spacing: [1.         0.73828125 0.73828125]
#
# before crop: (1, 133, 126, 192) after crop: (1, 133, 126, 192) spacing: [0.69999999 0.828125   0.828125  ]
#
# before crop: (1, 49, 120, 171) after crop: (1, 49, 120, 171) spacing: [2.4000001  0.68900001 0.68900001]
#
# case_226
# case_260
# before crop: (1, 50, 114, 151) after crop: (1, 50, 114, 151) spacing: [3.        0.8203125 0.8203125]
#
# case_219
# case_248
# case_242
# case_261
# case_208
# before crop: (1, 48, 119, 163) after crop: (1, 48, 119, 163) spacing: [3.         0.78710938 0.78710938]
#
# before crop: (1, 57, 136, 194) after crop: (1, 57, 136, 194) spacing: [2.         0.61328125 0.61328125]
#
# before crop: (1, 100, 149, 150) after crop: (1, 100, 149, 150) spacing: [1.         0.74699998 0.74699998]
#
# before crop: (1, 46, 85, 127) after crop: (1, 46, 85, 127) spacing: [3.         0.97656298 0.97656298]
#
# case_209
# case_265
# case_198
# case_255
# case_262
# before crop: (1, 54, 132, 171) after crop: (1, 54, 132, 171) spacing: [3.         0.90234375 0.90234375]
#
# before crop: (1, 91, 95, 226) after crop: (1, 91, 95, 226) spacing: [1.         0.71399999 0.71399999]
#
# case_263
# case_236
# case_215
# case_271
# case_249
# before crop: (1, 125, 97, 185) after crop: (1, 125, 97, 185) spacing: [0.80000001 0.78100002 0.78100002]
#
# before crop: (1, 61, 132, 175) after crop: (1, 61, 132, 175) spacing: [2.         0.79492188 0.79492188]
#
# before crop: (1, 47, 108, 224) after crop: (1, 47, 108, 224) spacing: [3.    0.662 0.662]
#
# case_237
# before crop: (1, 47, 113, 148) after crop: (1, 47, 113, 148) spacing: [3.         0.91100001 0.91100001]
#
# case_243
# before crop: (1, 111, 109, 169) after crop: (1, 111, 109, 169) spacing: [0.80000001 0.74023438 0.74023438]
#
# before crop: (1, 115, 89, 156) after crop: (1, 115, 89, 156) spacing: [0.80000001 0.87699997 0.87699997]
#
# case_231
# case_250
# before crop: (1, 54, 115, 178) after crop: (1, 54, 115, 178) spacing: [2.4000001 0.741     0.741    ]
#
# before crop: (1, 42, 108, 162) after crop: (1, 42, 108, 162) spacing: [3.    0.755 0.755]
#
# before crop: (1, 58, 133, 180) after crop: (1, 58, 133, 180) spacing: [2.4000001  0.60699999 0.60699999]
#
# case_232
# case_238
# before crop: (1, 160, 96, 156) after crop: (1, 160, 96, 156) spacing: [0.80102539 0.68599999 0.68599999]
#
# case_272
# before crop: (1, 30, 131, 266) after crop: (1, 30, 131, 266) spacing: [8.         0.39100599 0.39100599]
#
# case_239
# case_244
# before crop: (1, 52, 119, 179) after crop: (1, 52, 119, 179) spacing: [2.         0.82700002 0.82700002]
#
# before crop: (1, 132, 125, 195) after crop: (1, 132, 125, 195) spacing: [1.       0.671875 0.671875]
#
# case_273
# case_227
# before crop: (1, 95, 114, 148) after crop: (1, 95, 114, 148) spacing: [1.         0.87300003 0.87300003]
#
# case_180
# before crop: (1, 41, 158, 167) after crop: (1, 41, 158, 167) spacing: [2.4000001  0.39100599 0.39100599]
#
# case_251
# before crop: (1, 48, 121, 203) after crop: (1, 48, 121, 203) spacing: [3.         0.75585938 0.75585938]
#
# case_228
# before crop: (1, 58, 132, 170) after crop: (1, 58, 132, 170) spacing: [3.         0.78200001 0.78200001]
#
# case_240
# case_252
# before crop: (1, 227, 129, 178) after crop: (1, 227, 129, 178) spacing: [0.5        0.78200001 0.78200001]
#
# before crop: (1, 55, 77, 128) after crop: (1, 55, 77, 128) spacing: [2.4000001  0.89200002 0.89200002]
#
# before crop: (1, 106, 82, 129) after crop: (1, 106, 82, 129) spacing: [1.         0.96100003 0.96100003]
#
# case_277
# before crop: (1, 105, 111, 180) after crop: (1, 105, 111, 180) spacing: [1.         0.81199998 0.81199998]
#
# before crop: (1, 110, 113, 190) after crop: (1, 110, 113, 190) spacing: [0.75       0.80664062 0.80664062]
#
# case_210
# before crop: (1, 112, 120, 233) after crop: (1, 112, 120, 233) spacing: [0.80000001 0.77200001 0.77200001]
#
# case_220
# before crop: (1, 49, 152, 261) after crop: (1, 49, 152, 261) spacing: [3.       0.640625 0.640625]
#
# case_266
# case_283
# before crop: (1, 52, 101, 124) after crop: (1, 52, 101, 124) spacing: [3.         0.78200001 0.78200001]
#
# case_256
# before crop: (1, 127, 106, 154) after crop: (1, 127, 106, 154) spacing: [0.80000001 0.61799997 0.61799997]
#
# before crop: (1, 61, 114, 179) after crop: (1, 61, 114, 179) spacing: [2.         0.79101562 0.79101562]
#
# before crop: (1, 93, 91, 129) after crop: (1, 93, 91, 129) spacing: [1.         0.68599999 0.68599999]
#
# before crop: (1, 79, 150, 162) after crop: (1, 79, 150, 162) spacing: [1.5        0.84960938 0.84960938]
#
# case_284
# before crop: (1, 71, 102, 165) after crop: (1, 71, 102, 165) spacing: [1.5        0.88867188 0.88867188]
#
# case_257
# before crop: (1, 95, 116, 175) after crop: (1, 95, 116, 175) spacing: [1.         0.70499998 0.70499998]
#
# case_267
# before crop: (1, 102, 144, 167) after crop: (1, 102, 144, 167) spacing: [1.         0.74699998 0.74699998]
#
# before crop: (1, 50, 100, 155) after crop: (1, 50, 100, 155) spacing: [3.         0.67382812 0.67382812]
#
# case_216
# case_285
# case_221
# before crop: (1, 41, 272, 394) after crop: (1, 41, 272, 394) spacing: [3.         0.39100599 0.39100599]
#
# before crop: (1, 97, 111, 155) after crop: (1, 97, 111, 155) spacing: [1.         0.83099997 0.83099997]
#
# case_258
# before crop: (1, 61, 251, 309) after crop: (1, 61, 251, 309) spacing: [2.4000001 0.390053  0.390053 ]
#
# case_278
# before crop: (1, 42, 130, 169) after crop: (1, 42, 130, 169) spacing: [2.4000001  0.59500003 0.59500003]
#
# case_264
# before crop: (1, 62, 110, 185) after crop: (1, 62, 110, 185) spacing: [1.5       0.7421875 0.7421875]
#
# before crop: (1, 134, 133, 183) after crop: (1, 134, 133, 183) spacing: [0.80000001 0.78200001 0.78200001]
#
# case_222
# case_245
# before crop: (1, 40, 89, 149) after crop: (1, 40, 89, 149) spacing: [3.       0.640625 0.640625]
#
# before crop: (1, 124, 161, 224) after crop: (1, 124, 161, 224) spacing: [0.75       0.56445312 0.56445312]
#
# before crop: (1, 43, 210, 359) after crop: (1, 43, 210, 359) spacing: [3.         0.33092499 0.33092499]
#
# before crop: (1, 59, 103, 208) after crop: (1, 59, 103, 208) spacing: [2.         0.71484375 0.71484375]
#
# before crop: (1, 46, 216, 283) after crop: (1, 46, 216, 283) spacing: [3.         0.39100599 0.39100599]
#
# case_246
# case_274
# before crop: (1, 55, 264, 370) after crop: (1, 55, 264, 370) spacing: [3.         0.39100599 0.39100599]
#
# case_286
# case_233
# before crop: (1, 106, 116, 161) after crop: (1, 106, 116, 161) spacing: [0.80102539 0.70499998 0.70499998]
#
# case_234
# before crop: (1, 48, 110, 153) after crop: (1, 48, 110, 153) spacing: [3.         0.71679688 0.71679688]
#
# case_268
# before crop: (1, 55, 103, 215) after crop: (1, 55, 103, 215) spacing: [2.         0.70703125 0.70703125]
#
# before crop: (1, 58, 114, 185) after crop: (1, 58, 114, 185) spacing: [2.         0.68164062 0.68164062]
#
# case_269
# before crop: (1, 99, 98, 175) after crop: (1, 99, 98, 175) spacing: [1.         0.79882812 0.79882812]
#
# before crop: (1, 124, 96, 200) after crop: (1, 124, 96, 200) spacing: [0.80000001 0.78200001 0.78200001]
#
# case_279
# before crop: (1, 117, 115, 194) after crop: (1, 117, 115, 194) spacing: [0.80000001 0.72070312 0.72070312]
#
# case_287
# before crop: (1, 50, 109, 181) after crop: (1, 50, 109, 181) spacing: [3.         0.71700001 0.71700001]
#
# before crop: (1, 49, 203, 248) after crop: (1, 49, 203, 248) spacing: [3.       0.340462 0.340462]
#
# before crop: (1, 46, 89, 139) after crop: (1, 46, 89, 139) spacing: [3.         0.69921875 0.69921875]
#
# case_275
# case_270
# case_280
# case_288
# before crop: (1, 64, 98, 150) after crop: (1, 64, 98, 150) spacing: [2.         0.73242188 0.73242188]
#
# before crop: (1, 99, 119, 197) after crop: (1, 99, 119, 197) spacing: [1.    0.759 0.759]
#
# before crop: (1, 39, 100, 186) after crop: (1, 39, 100, 186) spacing: [4.         0.77539062 0.77539062]
#
# before crop: (1, 98, 169, 191) after crop: (1, 98, 169, 191) spacing: [1.         0.70899999 0.70899999]
#
# case_281
# case_276
# before crop: (1, 52, 114, 207) after crop: (1, 52, 114, 207) spacing: [3.         0.77148438 0.77148438]
#
# before crop: (1, 119, 166, 166) after crop: (1, 119, 166, 166) spacing: [1.         0.70899999 0.70899999]
#
# case_282
# before crop: (1, 43, 94, 140) after crop: (1, 43, 94, 140) spacing: [5.         0.61299998 0.61299998]
#
#
#
#
#  Task006_PancreasUHN
# number of threads:  (14, 14)
#
# Are we using the nonzero mask for normalization? OrderedDict([(0, False)])
# the median shape of the dataset is  [ 59.25       117.32       180.50266667]
# the max shape in the dataset is  [120.         205.25333333 288.248     ]
# the min shape in the dataset is  [31.5        69.93481055 89.15353711]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [ 59.25       117.32       180.50266667]
# generating configuration for 3d_fullres
# {0: {'batch_size': 2, 'num_pool_per_axis': [4, 5, 5], 'patch_size': array([ 64, 128, 192]), 'median_patient_size_in_voxels': array([ 59, 117, 181]), 'current_spacing': array([2.        , 0.73242188, 0.73242188]), 'original_spacing': array([2.        , 0.73242188, 0.73242188]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[1, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[1, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}}
# transpose forward [0, 1, 2]
# transpose backward [0, 1, 2]
# Initializing to run preprocessing
# npz folder: /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_cropped_data/Task006_PancreasUHN
# output_folder: /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN
# no separate z, order 3
# no separate z, order 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# no separate z, order 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 1
# no separate z, order 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# no separate z, order 1
# before: {'spacing': array([3.        , 0.69921875, 0.69921875]), 'spacing_transposed': array([3.        , 0.69921875, 0.69921875]), 'data.shape (data is transposed)': (1, 45, 157, 155)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 68, 150, 148)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_031.npz
# no separate z, order 1
# before: {'spacing': array([3.        , 0.75195312, 0.75195312]), 'spacing_transposed': array([3.        , 0.75195312, 0.75195312]), 'data.shape (data is transposed)': (1, 49, 130, 166)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 74, 133, 170)}
#
# 1 10000
# no separate z, order 1
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_055.npz
# no separate z, order 1
# before: {'spacing': array([2.      , 0.703125, 0.703125]), 'spacing_transposed': array([2.      , 0.703125, 0.703125]), 'data.shape (data is transposed)': (1, 59, 108, 127)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 59, 104, 122)}
#
# 1 10000
# 2 3379
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_061.npz
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([3.     , 0.78125, 0.78125]), 'spacing_transposed': array([3.     , 0.78125, 0.78125]), 'data.shape (data is transposed)': (1, 50, 124, 201)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 75, 132, 214)}
#
# no separate z, order 1
# 1 10000
# 2 5431
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_079.npz
# before: {'spacing': array([1.5       , 0.71679688, 0.71679688]), 'spacing_transposed': array([1.5       , 0.71679688, 0.71679688]), 'data.shape (data is transposed)': (1, 73, 97, 161)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 55, 95, 158)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_067.npz
# before: {'spacing': array([2.        , 0.70703125, 0.70703125]), 'spacing_transposed': array([2.        , 0.70703125, 0.70703125]), 'data.shape (data is transposed)': (1, 61, 127, 139)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 61, 123, 134)}
#
# 1 10000
# 2 6904
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_001.npz
# before: {'spacing': array([1.5       , 0.62890625, 0.62890625]), 'spacing_transposed': array([1.5       , 0.62890625, 0.62890625]), 'data.shape (data is transposed)': (1, 68, 143, 176)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 51, 123, 151)}
#
# 1 10000
# 2 342
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_007.npz
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.5       , 0.68359375, 0.68359375]), 'spacing_transposed': array([1.5       , 0.68359375, 0.68359375]), 'data.shape (data is transposed)': (1, 79, 124, 174)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 59, 116, 162)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_043.npz
# before: {'spacing': array([2.        , 0.76171875, 0.76171875]), 'spacing_transposed': array([2.        , 0.76171875, 0.76171875]), 'data.shape (data is transposed)': (1, 56, 102, 201)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 56, 106, 209)}
#
# 1 10000
# 2 9211
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_019.npz
# before: {'spacing': array([1.      , 0.828125, 0.828125]), 'spacing_transposed': array([1.      , 0.828125, 0.828125]), 'data.shape (data is transposed)': (1, 98, 90, 209)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 49, 102, 236)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_013.npz
# no separate z, order 1
# no separate z, order 3
# no separate z, order 3
# no separate z, order 3
# no separate z, order 3
# no separate z, order 3
# before: {'spacing': array([1.5      , 0.5390625, 0.5390625]), 'spacing_transposed': array([1.5      , 0.5390625, 0.5390625]), 'data.shape (data is transposed)': (1, 79, 153, 245)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 59, 113, 180)}
#
# 1 10000
# 2 2826
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_073.npz
# before: {'spacing': array([1.5      , 0.7421875, 0.7421875]), 'spacing_transposed': array([1.5      , 0.7421875, 0.7421875]), 'data.shape (data is transposed)': (1, 85, 130, 189)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 64, 132, 192)}
#
# 1 10000
# no separate z, order 3
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_025.npz
# separate z, order in z is 0 order inplane is 3
# before: {'spacing': array([1.       , 0.7265625, 0.7265625]), 'spacing_transposed': array([1.       , 0.7265625, 0.7265625]), 'data.shape (data is transposed)': (1, 117, 149, 204)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 58, 148, 202)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_037.npz
# no separate z, order 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# no separate z, order 1
# before: {'spacing': array([1.19995117, 0.61914062, 0.61914062]), 'spacing_transposed': array([1.19995117, 0.61914062, 0.61914062]), 'data.shape (data is transposed)': (1, 94, 106, 189)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 56, 90, 160)}
#
# before: {'spacing': array([3.       , 0.7734375, 0.7734375]), 'spacing_transposed': array([3.       , 0.7734375, 0.7734375]), 'data.shape (data is transposed)': (1, 49, 102, 167)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 74, 108, 176)}
#
# 1 10000
# 2 1120
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_032.npz
# 1 10000
# 2 7910
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_080.npz
# before: {'spacing': array([3.        , 0.72265625, 0.72265625]), 'spacing_transposed': array([3.        , 0.72265625, 0.72265625]), 'data.shape (data is transposed)': (1, 42, 87, 118)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 63, 86, 116)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_074.npz
# no separate z, order 1
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.        , 0.60546875, 0.60546875]), 'spacing_transposed': array([1.        , 0.60546875, 0.60546875]), 'data.shape (data is transposed)': (1, 106, 149, 207)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 53, 123, 171)}
#
# no separate z, order 1
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_068.npz
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# before: {'spacing': array([1.       , 0.7734375, 0.7734375]), 'spacing_transposed': array([1.       , 0.7734375, 0.7734375]), 'data.shape (data is transposed)': (1, 92, 111, 206)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 46, 117, 218)}
#
# 1 10000
# 2 674
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_020.npz
# no separate z, order 1
# no separate z, order 3
# before: {'spacing': array([1.20001221, 0.68359375, 0.68359375]), 'spacing_transposed': array([1.20001221, 0.68359375, 0.68359375]), 'data.shape (data is transposed)': (1, 106, 136, 200)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 64, 127, 187)}
#
# 1 10000
# 2 2882
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_056.npz
# no separate z, order 1
# before: {'spacing': array([1.5      , 0.6796875, 0.6796875]), 'spacing_transposed': array([1.5      , 0.6796875, 0.6796875]), 'data.shape (data is transposed)': (1, 85, 142, 218)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 64, 132, 202)}
#
# 1 10000
# 2 586
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_008.npz
# before: {'spacing': array([1.20001221, 0.64257812, 0.64257812]), 'spacing_transposed': array([1.20001221, 0.64257812, 0.64257812]), 'data.shape (data is transposed)': (1, 63, 85, 142)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 38, 75, 125)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_033.npz
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# before: {'spacing': array([0.6000061 , 0.62695312, 0.62695312]), 'spacing_transposed': array([0.6000061 , 0.62695312, 0.62695312]), 'data.shape (data is transposed)': (1, 161, 161, 241)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 48, 138, 206)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_002.npz
# before: {'spacing': array([3.     , 0.78125, 0.78125]), 'spacing_transposed': array([3.     , 0.78125, 0.78125]), 'data.shape (data is transposed)': (1, 52, 119, 220)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 78, 127, 235)}
#
# 1 10000
# 2 7056
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_038.npz
# separate z, order in z is 0 order inplane is 1
# no separate z, order 3
# before: {'spacing': array([3.        , 0.88476562, 0.88476562]), 'spacing_transposed': array([3.        , 0.88476562, 0.88476562]), 'data.shape (data is transposed)': (1, 45, 120, 137)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 68, 145, 165)}
#
# 1 10000
# 2 132
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_034.npz
# no separate z, order 1
# no separate z, order 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# no separate z, order 1
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([0.70001221, 0.69921875, 0.69921875]), 'spacing_transposed': array([0.70001221, 0.69921875, 0.69921875]), 'data.shape (data is transposed)': (1, 218, 215, 221)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 76, 205, 211)}
#
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_049.npz
# before: {'spacing': array([3.        , 0.71484375, 0.71484375]), 'spacing_transposed': array([3.        , 0.71484375, 0.71484375]), 'data.shape (data is transposed)': (1, 29, 120, 147)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 44, 117, 143)}
#
# 1 10000
# 2 5984
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_stage0/case_044.npz
# separate z, order in z is 0 order inplane is 3
# before: {'spacing': array([0.59997559, 0.80859375, 0.80859375]), 'spacing_transposed': array([0.59997559, 0.80859375, 0.80859375]), 'data.shape (data is transposed)': (1, 178, 111, 155)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 53, 123, 171)}
#
# 1 10000
# 2 7518
# ...
# before: {'spacing': array([1.   , 0.759, 0.759]), 'spacing_transposed': array([1.   , 0.759, 0.759]), 'data.shape (data is transposed)': (1, 99, 119, 197)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 99, 123, 204)}
#
# normalization...
# normalization done
# 1 10000
# 2 2023
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_280.npz
# separate z, order in z is 0 order inplane is 3
# before: {'spacing': array([0.80000001, 0.72070312, 0.72070312]), 'spacing_transposed': array([0.80000001, 0.72070312, 0.72070312]), 'data.shape (data is transposed)': (1, 117, 115, 194)}
# after:  {'spacing': array([0.80000001, 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 117, 113, 191)}
#
# normalization...
# normalization done
# 1 10000
# 2 1792
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_269.npz
# no separate z, order 1
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([2.        , 0.82700002, 0.82700002]), 'spacing_transposed': array([2.        , 0.82700002, 0.82700002]), 'data.shape (data is transposed)': (1, 52, 119, 179)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 52, 134, 202)}
#
# normalization...
# normalization done
# 1 10000
# 2 1549
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_239.npz
# no separate z, order 3
# before: {'spacing': array([3.        , 0.39100599, 0.39100599]), 'spacing_transposed': array([3.        , 0.39100599, 0.39100599]), 'data.shape (data is transposed)': (1, 41, 272, 394)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 41, 145, 210)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_216.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([2.        , 0.73242188, 0.73242188]), 'spacing_transposed': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is transposed)': (1, 64, 98, 150)}
# after:  {'spacing': array([2.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 64, 98, 150)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_270.npz
# no separate z, order 1
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([1.        , 0.72899997, 0.72899997]), 'spacing_transposed': array([1.        , 0.72899997, 0.72899997]), 'data.shape (data is transposed)': (1, 109, 126, 178)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 109, 125, 177)}
#
# normalization...
# normalization done
# 1 10000
# 2 2359
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_192.npz
# no separate z, order 3
# before: {'spacing': array([3.        , 0.78710938, 0.78710938]), 'spacing_transposed': array([3.        , 0.78710938, 0.78710938]), 'data.shape (data is transposed)': (1, 48, 119, 163)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 48, 128, 175)}
#
# normalization...
# normalization done
# 1 10000
# 2 5011
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_261.npz
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.        , 0.78200001, 0.78200001]), 'spacing_transposed': array([3.        , 0.78200001, 0.78200001]), 'data.shape (data is transposed)': (1, 58, 132, 170)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 58, 141, 182)}
#
# normalization...
# normalization done
# 1 10000
# 2 744
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_251.npz
# no separate z, order 3
# no separate z, order 3
# no separate z, order 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.        , 0.39100599, 0.39100599]), 'spacing_transposed': array([3.        , 0.39100599, 0.39100599]), 'data.shape (data is transposed)': (1, 46, 216, 283)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 46, 115, 151)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_222.npz
# separate z, order in z is 0 order inplane is 3
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.        , 0.70899999, 0.70899999]), 'spacing_transposed': array([1.        , 0.70899999, 0.70899999]), 'data.shape (data is transposed)': (1, 119, 166, 166)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 119, 161, 161)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_281.npz
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([2.4000001, 0.390053 , 0.390053 ]), 'spacing_transposed': array([2.4000001, 0.390053 , 0.390053 ]), 'data.shape (data is transposed)': (1, 61, 251, 309)}
# after:  {'spacing': array([2.4000001 , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 61, 134, 165)}
#
# normalization...
# normalization done
# 1 10000
# 2 4694
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_285.npz
# before: {'spacing': array([1.        , 0.96100003, 0.96100003]), 'spacing_transposed': array([1.        , 0.96100003, 0.96100003]), 'data.shape (data is transposed)': (1, 106, 82, 129)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 106, 108, 169)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_252.npz
# no separate z, order 1
# before: {'spacing': array([1.      , 0.671875, 0.671875]), 'spacing_transposed': array([1.      , 0.671875, 0.671875]), 'data.shape (data is transposed)': (1, 132, 125, 195)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 132, 115, 179)}
#
# normalization...
# separate z, order in z is 0 order inplane is 3
# normalization done
# 1 10000
# 2 5523
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_272.npz
# no separate z, order 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([5.        , 0.61299998, 0.61299998]), 'spacing_transposed': array([5.        , 0.61299998, 0.61299998]), 'data.shape (data is transposed)': (1, 43, 94, 140)}
# after:  {'spacing': array([5.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 43, 79, 117)}
#
# normalization...
# normalization done
# 1 10000
# 2 1989
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_282.npz
# no separate z, order 1
# no separate z, order 3
# before: {'spacing': array([1.5       , 0.84960938, 0.84960938]), 'spacing_transposed': array([1.5       , 0.84960938, 0.84960938]), 'data.shape (data is transposed)': (1, 79, 150, 162)}
# after:  {'spacing': array([1.5       , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 79, 174, 188)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_256.npz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.        , 0.67382812, 0.67382812]), 'spacing_transposed': array([3.        , 0.67382812, 0.67382812]), 'data.shape (data is transposed)': (1, 50, 100, 155)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 50, 92, 143)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_257.npz
# no separate z, order 1
# no separate z, order 1
# no separate z, order 3
# before: {'spacing': array([0.5       , 0.78200001, 0.78200001]), 'spacing_transposed': array([0.5       , 0.78200001, 0.78200001]), 'data.shape (data is transposed)': (1, 227, 129, 178)}
# after:  {'spacing': array([0.5       , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 227, 138, 190)}
#
# normalization...
# normalization done
# before: {'spacing': array([0.80102539, 0.70499998, 0.70499998]), 'spacing_transposed': array([0.80102539, 0.70499998, 0.70499998]), 'data.shape (data is transposed)': (1, 106, 116, 161)}
# after:  {'spacing': array([0.80102539, 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 106, 112, 155)}
#
# normalization...
# normalization done
# 1 10000
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_233.npz
# 2 5064
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_240.npz
# before: {'spacing': array([0.80000001, 0.78200001, 0.78200001]), 'spacing_transposed': array([0.80000001, 0.78200001, 0.78200001]), 'data.shape (data is transposed)': (1, 124, 96, 200)}
# after:  {'spacing': array([0.80000001, 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 124, 102, 214)}
#
# normalization...
# normalization done
# 1 10000
# 2 3975
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_286.npz
# no separate z, order 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([1.5      , 0.7421875, 0.7421875]), 'spacing_transposed': array([1.5      , 0.7421875, 0.7421875]), 'data.shape (data is transposed)': (1, 62, 110, 185)}
# after:  {'spacing': array([1.5       , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 62, 111, 187)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_258.npz
# before: {'spacing': array([3.        , 0.71700001, 0.71700001]), 'spacing_transposed': array([3.        , 0.71700001, 0.71700001]), 'data.shape (data is transposed)': (1, 50, 109, 181)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 50, 107, 177)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_287.npz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.        , 0.90234375, 0.90234375]), 'spacing_transposed': array([3.        , 0.90234375, 0.90234375]), 'data.shape (data is transposed)': (1, 54, 132, 171)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 54, 163, 211)}
#
# normalization...
# normalization done
# 1 10000
# 2 1027
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_262.npz
# no separate z, order 3
# no separate z, order 3
# no separate z, order 1
# no separate z, order 1
# before: {'spacing': array([1.5       , 0.88867188, 0.88867188]), 'spacing_transposed': array([1.5       , 0.88867188, 0.88867188]), 'data.shape (data is transposed)': (1, 71, 102, 165)}
# after:  {'spacing': array([1.5       , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 71, 124, 200)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_263.npz
# before: {'spacing': array([1.        , 0.70899999, 0.70899999]), 'spacing_transposed': array([1.        , 0.70899999, 0.70899999]), 'data.shape (data is transposed)': (1, 98, 169, 191)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 98, 164, 185)}
#
# normalization...
# normalization done
# 1 10000
# 2 2444
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_288.npz
# separate z, order in z is 0 order inplane is 3
# no separate z, order 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.      , 0.340462, 0.340462]), 'spacing_transposed': array([3.      , 0.340462, 0.340462]), 'data.shape (data is transposed)': (1, 49, 203, 248)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 49, 94, 115)}
#
# normalization...
# normalization done
# 1 10000
# 2 6759
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_234.npz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.      , 0.640625, 0.640625]), 'spacing_transposed': array([3.      , 0.640625, 0.640625]), 'data.shape (data is transposed)': (1, 40, 89, 149)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 40, 78, 130)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_264.npz
# no separate z, order 1
# before: {'spacing': array([0.75      , 0.56445312, 0.56445312]), 'spacing_transposed': array([0.75      , 0.56445312, 0.56445312]), 'data.shape (data is transposed)': (1, 124, 161, 224)}
# after:  {'spacing': array([0.75      , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 124, 124, 173)}
#
# normalization...
# normalization done
# 1 10000
# 2 1033
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_273.npz
# no separate z, order 3
# no separate z, order 1
# before: {'spacing': array([1.        , 0.79882812, 0.79882812]), 'spacing_transposed': array([1.        , 0.79882812, 0.79882812]), 'data.shape (data is transposed)': (1, 99, 98, 175)}
# after:  {'spacing': array([1.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 99, 107, 191)}
#
# normalization...
# normalization done
# 1 10000
# 2 10000
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_274.npz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([4.        , 0.77539062, 0.77539062]), 'spacing_transposed': array([4.        , 0.77539062, 0.77539062]), 'data.shape (data is transposed)': (1, 39, 100, 186)}
# after:  {'spacing': array([4.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 39, 106, 197)}
#
# normalization...
# normalization done
# 1 10000
# 2 2555
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_275.npz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# before: {'spacing': array([3.        , 0.77148438, 0.77148438]), 'spacing_transposed': array([3.        , 0.77148438, 0.77148438]), 'data.shape (data is transposed)': (1, 52, 114, 207)}
# after:  {'spacing': array([3.        , 0.73242188, 0.73242188]), 'data.shape (data is resampled)': (1, 52, 120, 218)}
#
# normalization...
# normalization done
# 1 10000
# 2 4739
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1_2D_stage0/case_276.npz

# %%
! nnUNet_train 3d_fullres nnUNetTrainerV2_Custom Task006_PancreasUHN 0
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.custom_trainer.nnUNetTrainerV2_Custom'>
# For that I will be using the following configuration:
# num_classes:  2
# modalities:  {0: 'CT'}
# use_mask_for_norm OrderedDict([(0, False)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'CT')])
# stages...
#
# stage:  0
# {'batch_size': 2, 'num_pool_per_axis': [4, 5, 5], 'patch_size': array([ 64, 128, 192]), 'median_patient_size_in_voxels': array([ 59, 117, 181]), 'current_spacing': array([2.        , 0.73242188, 0.73242188]), 'original_spacing': array([2.        , 0.73242188, 0.73242188]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[1, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[1, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/nnUNetData_plans_v2.1
# ###############################################
#
#         #################################################################
#
#                         Initializing Custom Trainer
#                         Using Custom U-Net: True
#                         Only Run Eval: False
#
#         #################################################################
#
# loading dataset
# loading all case properties
# 2024-07-30 19:56:13.092901: Using splits from existing split file: /scratch/alif/nnUNet/nnUNet_preprocessed/Task006_PancreasUHN/splits_final.pkl
# 2024-07-30 19:56:30.993395: The split file contains 5 splits.
# 2024-07-30 19:56:30.996365: Desired fold for training: 0
# 2024-07-30 19:56:30.999167: This split has 230 training and 58 validation cases.
# unpacking dataset
# done
# 2024-07-30 19:56:38.577295: lr: 0.01
# using pin_memory on device 0
# using pin_memory on device 0
# 2024-07-30 19:57:03.658205: Unable to plot network architecture:
# 2024-07-30 19:57:03.660237: module 'torch.onnx' has no attribute '_optimize_trace'
# 2024-07-30 19:57:03.661439:
# printing the network instead:
#
# 2024-07-30 19:57:03.662740: CustomUNet(
#   (conv_blocks_localization): ModuleList(
#     (0): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(640, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (1): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(512, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (2): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (3): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#     (4): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (conv_blocks_context): ModuleList(
#     (0): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(1, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1))
#           (instnorm): InstanceNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (1): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (2): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (3): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (4): StackedConvLayers(
#       (blocks): Sequential(
#         (0): ConvDropoutNormNonlin(
#           (conv): Conv3d(256, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#         (1): ConvDropoutNormNonlin(
#           (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#           (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#           (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#         )
#       )
#     )
#     (5): Sequential(
#       (0): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#       (1): StackedConvLayers(
#         (blocks): Sequential(
#           (0): ConvDropoutNormNonlin(
#             (conv): Conv3d(320, 320, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             (instnorm): InstanceNorm3d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#             (lrelu): LeakyReLU(negative_slope=0.01, inplace=True)
#           )
#         )
#       )
#     )
#   )
#   (td): ModuleList()
#   (tu): ModuleList(
#     (0): ConvTranspose3d(320, 320, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (1): ConvTranspose3d(320, 256, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (2): ConvTranspose3d(256, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (3): ConvTranspose3d(128, 64, kernel_size=(2, 2, 2), stride=(2, 2, 2), bias=False)
#     (4): ConvTranspose3d(64, 32, kernel_size=(1, 2, 2), stride=(1, 2, 2), bias=False)
#   )
#   (seg_outputs): ModuleList(
#     (0): Conv3d(320, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (1): Conv3d(256, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (2): Conv3d(128, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (3): Conv3d(64, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (4): Conv3d(32, 3, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   )
#   (global_avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Linear(in_features=1280, out_features=3, bias=True)
# )
# 2024-07-30 19:57:03.667275:
#
# 2024-07-30 19:57:03.681575:
# epoch:  0
# Epoch 1/1000: 100%|███████████| 250/250 [04:10<00:00,  1.00s/it, loss=1.0973694]
# 2024-07-30 20:01:13.948813: train loss : 1.9607
# 100%|███████████████████████████████████████████| 50/50 [00:11<00:00,  4.31it/s]
# 2024-07-30 20:01:25.542734: validation loss: 1.0973
# 2024-07-30 20:01:25.544230: Average global foreground Dice: [0.3743, 0.0532]
# 2024-07-30 20:01:25.545509: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2024-07-30 20:01:25.546797: Average classification accuracy: 0.37
# 2024-07-30 20:01:25.547828: 37.0 correct out of 100 total.
# 2024-07-30 20:01:26.269868: lr: 0.009991
# 2024-07-30 20:01:26.271172: This epoch took 262.587456 s
#
# 2024-07-30 20:01:26.272420:
# epoch:  1
# Epoch 2/1000: 100%|███████████| 250/250 [03:06<00:00,  1.34it/s, loss=0.6026279]
# 2024-07-30 20:04:32.619131: train loss : 1.1884
# 100%|███████████████████████████████████████████| 50/50 [00:12<00:00,  4.10it/s]
# 2024-07-30 20:04:44.827521: validation loss: 1.1314
# 2024-07-30 20:04:44.828834: Average global foreground Dice: [0.4065, 0.2013]
# 2024-07-30 20:04:44.830169: (interpret this as an estimate for the Dice of the different classes. This is not exact.)
# 2024-07-30 20