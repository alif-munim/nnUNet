# %% [markdown]
# # Hippocampus Dataset

# %%
def make_if_dont_exist(folder_path,overwrite=False):
    """
    creates a folder if it does not exists
    input: 
    folder_path : relative path of the folder which needs to be created
    over_write :(default: False) if True overwrite the existing folder 
    """
    if os.path.exists(folder_path):
        
        if not overwrite:
            print(f"{folder_path} exists.")
        else:
            print(f"{folder_path} overwritten")
            shutil.rmtree(folder_path)
            os.makedirs(folder_path)

    else:
      os.makedirs(folder_path)
      print(f"{folder_path} created!")

# Maybe move path of preprocessed data directly on content - this may be signifcantely faster!
print("Current Working Directory {}".format(os.getcwd()))
path_dict = {
    "nnUNet_raw" : os.path.join(os.getcwd(), "nnUNet_raw"), 
    "nnUNet_preprocessed" : os.path.join(os.getcwd(), "nnUNet_preprocessed"), # 1 experiment: 1 epoch took 112s
    "nnUNet_results" : os.path.join(os.getcwd(), "nnUNet_results"),
    "RAW_DATA_PATH" : os.path.join(os.getcwd(), "original_data"), # This is used here only for convenience (not necessary for nnU-Net)!
}

# Write paths to environment variables
for env_var, path in path_dict.items():
  os.environ[env_var] = path 

# Check whether all environment variables are set correct!
for env_var, path in path_dict.items():
  if os.getenv(env_var) != path:
    print("Error:")
    print("Environment Variable {} is not set correctly!".format(env_var))
    print("Should be {}".format(path))
    print("Variable is {}".format(os.getenv(env_var)))
  make_if_dont_exist(path, overwrite=False)

print("If No Error Occured Continue Forward. =)")
# Out:
# Current Working Directory /scratch/alif/nnUNet
# /scratch/alif/nnUNet/nnUNet_raw exists.
# /scratch/alif/nnUNet/nnUNet_preprocessed exists.
# /scratch/alif/nnUNet/nnUNet_results exists.
# /scratch/alif/nnUNet/original_data exists.
# If No Error Occured Continue Forward. =)

# %%
# os.environ['nnUNet_raw_data_base'] = '/scratch/alif/nnUNet/original_data'
os.environ['nnUNet_raw_data_base'] = '/scratch/alif/nnUNet/nnUNet_raw_data_base'
os.environ['nnUNet_preprocessed'] = '/scratch/alif/nnUNet/nnUNet_preprocessed'
os.environ['RESULTS_FOLDER'] = '/scratch/alif/nnUNet/nnUNet_trained_models'

# %%
train_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTr'
test_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTs'

# %%
import os
def remove_suffix(images_dir):
    image_files = sorted(os.listdir(images_dir))
    
    for i, img_file in enumerate(image_files):
        new_image_name = img_file.replace('_0000.', '.')
        os.rename(os.path.join(images_dir, img_file), os.path.join(images_dir, new_image_name))
        
remove_suffix(train_dir)
# remove_suffix(test_dir)

# %%
import os
def add_suffix(images_dir):
    image_files = sorted(os.listdir(images_dir))
    
    for i, img_file in enumerate(image_files):
        new_image_name = img_file.replace('.nii.gz', '_0000.nii.gz')
        os.rename(os.path.join(images_dir, img_file), os.path.join(images_dir, new_image_name))
        
# add_suffix(train_dir)
add_suffix(test_dir)

# %%
! rm nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTs/._*
# Out:
# rm: cannot remove 'nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTs/._*': No such file or directory

# %%
! ls nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTr | wc -l
! ls nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTs | wc -l
# Out:
# 260
# 130

# %% [markdown]
# **Examples** <br>
# Only train and test (not labels) should have suffixes.
# - nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTr/hippocampus_001_0000.nii.gz
# - nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/labelsTr/hippocampus_001.nii.gz
# - nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus/imagesTs/hippocampus_196_0000.nii.gz
#
# <br>
#
# **JSON** <br>
# Should have no suffixes.
#
# ```json
# {
#  "name": "Hippocampus",
#  "description": "Left and right hippocampus segmentation",
# "reference": " Vanderbilt University Medical Center",
# "licence":"CC-BY-SA 4.0",
# "relase":"1.0 04/05/2018",
# "tensorImageSize": "3D",
# "modality": {
#    "0": "MRI"
#  },
#  "labels": {
#    "0": "background",
#    "1": "Anterior",
#    "2": "Posterior"
#  },
#  "numTraining": 260,
#  "numTest": 130,
#  "training":[{"image":"./imagesTr/hippocampus_367.nii.gz","label":"./labelsTr/hippocampus_367.nii.gz"},{"image":"./imagesTr/hippocampus_304.nii.gz","label":"./labelsTr/hippocampus_304.nii.gz"},{"image":"./imagesTr/hippocampus_204.nii.gz","label":"./labelsTr/hippocampus_204.nii.gz"},{"image":"./imagesTr/hippocampus_279.nii.gz","label":"./labelsTr/hippocampus_279.nii.gz"},{"image":"./imagesTr/hippocampus_308.nii.gz","label":"./labelsTr/hippocampus_308.nii.gz"},{"image":"./imagesTr/hippocampus_375.nii.gz","label":"./labelsTr/hippocampus_375.nii.gz"},
#              ...]
#  "test":["./imagesTs/hippocampus_267.nii.gz","./imagesTs/hippocampus_379.nii.gz","./imagesTs/hippocampus_208.nii.gz","./imagesTs/hippocampus_275.nii.gz", ...]
# }
#
# ```

# %%
import os
import json

def create_dataset_json(base_dir, task_name, num_training, num_test):
    
    imagesTr_dir = os.path.join(base_dir, task_name, 'imagesTr')
    labelsTr_dir = os.path.join(base_dir, task_name, 'labelsTr')
    imagesTs_dir = os.path.join(base_dir, task_name, 'imagesTs')

    # Get list of training and test images
    training_images = sorted(os.listdir(imagesTr_dir))
    test_images = sorted(os.listdir(imagesTs_dir))

    # Ensure the number of requested training and test images does not exceed available images
    num_training = min(num_training, len(training_images))
    num_test = min(num_test, len(test_images))

    # Create the dataset dictionary
    dataset = {
        "name": "Hippocampus",
        "description": "Left and right hippocampus segmentation",
        "tensorImageSize": "3D",
        "reference": "",
        "licence": "",
        "release": "0.0",
        "modality": {
            "0": "MRI"
        },
        "labels": {
            "0":"background",
            "1":"Anterior",
            "2":"Posterior"
            # Add other structures as needed
        },
        "numTraining": num_training,
        "numTest": num_test,
        "training": [],
        "test": []
    }

    # Populate the training field
    for i in range(num_training):
        dataset['training'].append({
            # "image": f"./imagesTr/{training_images[i]}",
            "image": f"./imagesTr/{training_images[i].replace('_0000.nii.gz', '.nii.gz')}",
            "label": f"./labelsTr/{training_images[i].replace('_0000.nii.gz', '.nii.gz')}"
        })

    # Populate the test field
    for i in range(num_test):
        dataset['test'].append(f"./imagesTs/{test_images[i]}")
        # dataset['test'].append(f"./imagesTs/{test_images[i].replace('_0000.nii.gz', '.nii.gz')}")

    # Save the dataset.json file
    with open(os.path.join(base_dir, task_name, 'dataset.json'), 'w') as f:
        json.dump(dataset, f, indent=4)

# Define the parameters
base_dir = '/scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/'
task_name = 'Task004_Hippocampus'  # Replace 002 with the actual task number
num_training = 260  # Set the number of training samples
num_test = 130  # Set the number of test samples

# Create the dataset.json file
create_dataset_json(base_dir, task_name, num_training, num_test)
print('Done')
# Out:
# Done

# %% [markdown]
# **WARNING** <br>
# The raw data should be located in `nnUNet/nnUNet_raw_data_base/nnUNet_raw_data/Task004_Hippocampus` <br>
# It must have 3 digits to specify the task ID.

# %%
! nnUNet_plan_and_preprocess -t 04 --verify_dataset_integrity
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# Verifying training set
# checking case hippocampus_367
# checking case hippocampus_304
# checking case hippocampus_204
# checking case hippocampus_279
# checking case hippocampus_308
# checking case hippocampus_375
# checking case hippocampus_216
# checking case hippocampus_316
# checking case hippocampus_089
# checking case hippocampus_189
# checking case hippocampus_243
# checking case hippocampus_343
# checking case hippocampus_220
# checking case hippocampus_097
# checking case hippocampus_320
# checking case hippocampus_197
# checking case hippocampus_351
# checking case hippocampus_251
# checking case hippocampus_185
# checking case hippocampus_332
# checking case hippocampus_232
# checking case hippocampus_298
# checking case hippocampus_152
# checking case hippocampus_052
# checking case hippocampus_386
# checking case hippocampus_286
# checking case hippocampus_040
# checking case hippocampus_294
# checking case hippocampus_023
# checking case hippocampus_394
# checking case hippocampus_123
# checking case hippocampus_176
# checking case hippocampus_015
# checking case hippocampus_068
# checking case hippocampus_019
# checking case hippocampus_164
# checking case hippocampus_064
# checking case hippocampus_107
# checking case hippocampus_007
# checking case hippocampus_296
# checking case hippocampus_288
# checking case hippocampus_042
# checking case hippocampus_142
# checking case hippocampus_133
# checking case hippocampus_033
# checking case hippocampus_150
# checking case hippocampus_050
# checking case hippocampus_105
# checking case hippocampus_178
# checking case hippocampus_166
# checking case hippocampus_017
# checking case hippocampus_109
# checking case hippocampus_074
# checking case hippocampus_174
# checking case hippocampus_314
# checking case hippocampus_269
# checking case hippocampus_277
# checking case hippocampus_318
# checking case hippocampus_265
# checking case hippocampus_330
# checking case hippocampus_087
# checking case hippocampus_230
# checking case hippocampus_199
# checking case hippocampus_099
# checking case hippocampus_353
# checking case hippocampus_253
# checking case hippocampus_222
# checking case hippocampus_095
# checking case hippocampus_322
# checking case hippocampus_195
# checking case hippocampus_341
# checking case hippocampus_070
# checking case hippocampus_170
# checking case hippocampus_101
# checking case hippocampus_001
# checking case hippocampus_162
# checking case hippocampus_380
# checking case hippocampus_037
# checking case hippocampus_280
# checking case hippocampus_154
# checking case hippocampus_058
# checking case hippocampus_158
# checking case hippocampus_292
# checking case hippocampus_025
# checking case hippocampus_125
# checking case hippocampus_046
# checking case hippocampus_146
# checking case hippocampus_226
# checking case hippocampus_091
# checking case hippocampus_326
# checking case hippocampus_245
# checking case hippocampus_345
# checking case hippocampus_238
# checking case hippocampus_338
# checking case hippocampus_349
# checking case hippocampus_249
# checking case hippocampus_334
# checking case hippocampus_083
# checking case hippocampus_234
# checking case hippocampus_257
# checking case hippocampus_302
# checking case hippocampus_361
# checking case hippocampus_261
# checking case hippocampus_210
# checking case hippocampus_310
# checking case hippocampus_373
# checking case hippocampus_355
# checking case hippocampus_328
# checking case hippocampus_228
# checking case hippocampus_181
# checking case hippocampus_336
# checking case hippocampus_236
# checking case hippocampus_259
# checking case hippocampus_359
# checking case hippocampus_224
# checking case hippocampus_093
# checking case hippocampus_193
# checking case hippocampus_212
# checking case hippocampus_363
# checking case hippocampus_263
# checking case hippocampus_300
# checking case hippocampus_160
# checking case hippocampus_060
# checking case hippocampus_003
# checking case hippocampus_172
# checking case hippocampus_011
# checking case hippocampus_044
# checking case hippocampus_144
# checking case hippocampus_039
# checking case hippocampus_290
# checking case hippocampus_390
# checking case hippocampus_127
# checking case hippocampus_156
# checking case hippocampus_056
# checking case hippocampus_148
# checking case hippocampus_048
# checking case hippocampus_135
# checking case hippocampus_035
# checking case hippocampus_282
# checking case hippocampus_169
# checking case hippocampus_114
# checking case hippocampus_014
# checking case hippocampus_177
# checking case hippocampus_077
# checking case hippocampus_006
# checking case hippocampus_106
# checking case hippocampus_065
# checking case hippocampus_165
# checking case hippocampus_287
# checking case hippocampus_130
# checking case hippocampus_387
# checking case hippocampus_053
# checking case hippocampus_299
# checking case hippocampus_295
# checking case hippocampus_141
# checking case hippocampus_041
# checking case hippocampus_321
# checking case hippocampus_221
# checking case hippocampus_096
# checking case hippocampus_242
# checking case hippocampus_188
# checking case hippocampus_088
# checking case hippocampus_084
# checking case hippocampus_233
# checking case hippocampus_184
# checking case hippocampus_333
# checking case hippocampus_250
# checking case hippocampus_350
# checking case hippocampus_378
# checking case hippocampus_205
# checking case hippocampus_305
# checking case hippocampus_366
# checking case hippocampus_317
# checking case hippocampus_217
# checking case hippocampus_374
# checking case hippocampus_274
# checking case hippocampus_309
# checking case hippocampus_252
# checking case hippocampus_352
# checking case hippocampus_098
# checking case hippocampus_231
# checking case hippocampus_331
# checking case hippocampus_340
# checking case hippocampus_194
# checking case hippocampus_223
# checking case hippocampus_094
# checking case hippocampus_376
# checking case hippocampus_276
# checking case hippocampus_368
# checking case hippocampus_268
# checking case hippocampus_215
# checking case hippocampus_264
# checking case hippocampus_219
# checking case hippocampus_319
# checking case hippocampus_207
# checking case hippocampus_067
# checking case hippocampus_004
# checking case hippocampus_104
# checking case hippocampus_175
# checking case hippocampus_075
# checking case hippocampus_108
# checking case hippocampus_008
# checking case hippocampus_143
# checking case hippocampus_389
# checking case hippocampus_289
# checking case hippocampus_297
# checking case hippocampus_020
# checking case hippocampus_051
# checking case hippocampus_132
# checking case hippocampus_385
# checking case hippocampus_260
# checking case hippocampus_360
# checking case hippocampus_203
# checking case hippocampus_303
# checking case hippocampus_372
# checking case hippocampus_311
# checking case hippocampus_244
# checking case hippocampus_327
# checking case hippocampus_190
# checking case hippocampus_227
# checking case hippocampus_090
# checking case hippocampus_356
# checking case hippocampus_235
# checking case hippocampus_335
# checking case hippocampus_248
# checking case hippocampus_155
# checking case hippocampus_036
# checking case hippocampus_136
# checking case hippocampus_381
# checking case hippocampus_393
# checking case hippocampus_124
# checking case hippocampus_024
# checking case hippocampus_171
# checking case hippocampus_163
# checking case hippocampus_126
# checking case hippocampus_026
# checking case hippocampus_138
# checking case hippocampus_038
# checking case hippocampus_145
# checking case hippocampus_045
# checking case hippocampus_034
# checking case hippocampus_383
# checking case hippocampus_049
# checking case hippocampus_149
# checking case hippocampus_057
# checking case hippocampus_157
# checking case hippocampus_102
# checking case hippocampus_161
# checking case hippocampus_173
# checking case hippocampus_370
# checking case hippocampus_301
# checking case hippocampus_180
# checking case hippocampus_337
# checking case hippocampus_229
# checking case hippocampus_329
# checking case hippocampus_354
# checking case hippocampus_325
# checking case hippocampus_225
# checking case hippocampus_092
# checking case hippocampus_358
# Verifying label values
# Expected label values are [0, 1, 2]
# Labels OK
# Verifying test set
# Dataset OK
# hippocampus_367
# hippocampus_189
# hippocampus_185
# hippocampus_294
# hippocampus_064
# hippocampus_150
# hippocampus_314
# hippocampus_099
# before crop: (1, 34, 49, 37) after crop: (1, 34, 49, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 27, 52, 33) after crop: (1, 27, 52, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 49, 35) after crop: (1, 33, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 53, 35) after crop: (1, 30, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 53, 37) after crop: (1, 33, 53, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 53, 35) after crop: (1, 35, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 44, 44, 35) after crop: (1, 44, 44, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 57, 36) after crop: (1, 37, 57, 36) spacing: [1. 1. 1.]
#
# hippocampus_353
# before crop: (1, 31, 51, 32) after crop: (1, 31, 51, 32) spacing: [1. 1. 1.]
#
# hippocampus_023
# hippocampus_107
# hippocampus_269
# hippocampus_243
# before crop: (1, 35, 51, 35) after crop: (1, 35, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 49, 35) after crop: (1, 37, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 55, 35) after crop: (1, 34, 55, 35) spacing: [1. 1. 1.]
#
# hippocampus_050
# before crop: (1, 24, 53, 34) after crop: (1, 24, 53, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 49, 38) after crop: (1, 38, 49, 38) spacing: [1. 1. 1.]
#
# hippocampus_394
# hippocampus_007
# hippocampus_277
# before crop: (1, 32, 52, 36) after crop: (1, 32, 52, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 29, 59, 33) after crop: (1, 29, 59, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 47, 34) after crop: (1, 40, 47, 34) spacing: [1. 1. 1.]
#
# hippocampus_304
# hippocampus_332
# hippocampus_105
# before crop: (1, 38, 48, 36) after crop: (1, 38, 48, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 47, 33) after crop: (1, 37, 47, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 52, 35) after crop: (1, 33, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_296
# hippocampus_123
# before crop: (1, 35, 54, 35) after crop: (1, 35, 54, 35) spacing: [1. 1. 1.]
#
# hippocampus_204
# before crop: (1, 38, 53, 32) after crop: (1, 38, 53, 32) spacing: [1. 1. 1.]
# hippocampus_232
#
# before crop: (1, 43, 44, 36) after crop: (1, 43, 44, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 48, 36) after crop: (1, 39, 48, 36) spacing: [1. 1. 1.]
#
# hippocampus_178
# hippocampus_288
# before crop: (1, 41, 44, 35) after crop: (1, 41, 44, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 50, 38) after crop: (1, 42, 50, 38) spacing: [1. 1. 1.]
#
# hippocampus_298
# hippocampus_176
# hippocampus_166
# before crop: (1, 33, 50, 37) after crop: (1, 33, 50, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 50, 35) after crop: (1, 36, 50, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 31, 49, 36) after crop: (1, 31, 49, 36) spacing: [1. 1. 1.]
#
# hippocampus_152
# hippocampus_017
# before crop: (1, 37, 53, 36) after crop: (1, 37, 53, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 48, 35) after crop: (1, 32, 48, 35) spacing: [1. 1. 1.]
#
# hippocampus_109
# hippocampus_052
# before crop: (1, 36, 49, 36) after crop: (1, 36, 49, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 52, 34) after crop: (1, 40, 52, 34) spacing: [1. 1. 1.]
#
# hippocampus_386
# before crop: (1, 40, 45, 37) after crop: (1, 40, 45, 37) spacing: [1. 1. 1.]
#
# hippocampus_286
# before crop: (1, 46, 45, 37) after crop: (1, 46, 45, 37) spacing: [1. 1. 1.]
#
# hippocampus_040
# hippocampus_343
# hippocampus_318
# hippocampus_253
# before crop: (1, 38, 45, 32) after crop: (1, 38, 45, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 31, 51, 34) after crop: (1, 31, 51, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 52, 36) after crop: (1, 37, 52, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 51, 37) after crop: (1, 33, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_265
# before crop: (1, 34, 54, 31) after crop: (1, 34, 54, 31) spacing: [1. 1. 1.]
#
# hippocampus_330
# before crop: (1, 33, 55, 35) after crop: (1, 33, 55, 35) spacing: [1. 1. 1.]
#
# hippocampus_087
# hippocampus_222
# hippocampus_170
# before crop: (1, 32, 55, 35) after crop: (1, 32, 55, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 49, 34) after crop: (1, 36, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 34) after crop: (1, 40, 48, 34) spacing: [1. 1. 1.]
#
# hippocampus_220
# hippocampus_230
# hippocampus_095
# before crop: (1, 40, 45, 39) after crop: (1, 40, 45, 39) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 49, 34) after crop: (1, 37, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 49, 34) after crop: (1, 39, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_322
# before crop: (1, 37, 47, 38) after crop: (1, 37, 47, 38) spacing: [1. 1. 1.]
#
# hippocampus_199
# before crop: (1, 26, 52, 37) after crop: (1, 26, 52, 37) spacing: [1. 1. 1.]
#
# hippocampus_101
# before crop: (1, 32, 52, 36) after crop: (1, 32, 52, 36) spacing: [1. 1. 1.]
#
# hippocampus_195
# before crop: (1, 28, 53, 33) after crop: (1, 28, 53, 33) spacing: [1. 1. 1.]
#
# hippocampus_097
# hippocampus_158
# before crop: (1, 34, 48, 37) after crop: (1, 34, 48, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 52, 38) after crop: (1, 36, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_001
# hippocampus_341
# before crop: (1, 35, 51, 35) after crop: (1, 35, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 48, 34) after crop: (1, 35, 48, 34) spacing: [1. 1. 1.]
#
# hippocampus_070
# hippocampus_162
# before crop: (1, 38, 50, 37) after crop: (1, 38, 50, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 51, 38) after crop: (1, 37, 51, 38) spacing: [1. 1. 1.]
#
# hippocampus_245
# before crop: (1, 42, 48, 35) after crop: (1, 42, 48, 35) spacing: [1. 1. 1.]
#
# hippocampus_380
# before crop: (1, 42, 46, 35) after crop: (1, 42, 46, 35) spacing: [1. 1. 1.]
#
# hippocampus_345
# before crop: (1, 30, 49, 32) after crop: (1, 30, 49, 32) spacing: [1. 1. 1.]
#
# hippocampus_238
# hippocampus_037
# before crop: (1, 36, 56, 37) after crop: (1, 36, 56, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 51, 34) after crop: (1, 32, 51, 34) spacing: [1. 1. 1.]
#
# hippocampus_338
# hippocampus_280
# before crop: (1, 43, 43, 37) after crop: (1, 43, 43, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 47, 37) after crop: (1, 32, 47, 37) spacing: [1. 1. 1.]
#
# hippocampus_349
# before crop: (1, 34, 50, 34) after crop: (1, 34, 50, 34) spacing: [1. 1. 1.]
#
# hippocampus_249
# before crop: (1, 34, 52, 32) after crop: (1, 34, 52, 32) spacing: [1. 1. 1.]
#
# hippocampus_334
# before crop: (1, 36, 47, 34) after crop: (1, 36, 47, 34) spacing: [1. 1. 1.]
#
# hippocampus_154
# before crop: (1, 42, 46, 35) after crop: (1, 42, 46, 35) spacing: [1. 1. 1.]
#
# hippocampus_058
# before crop: (1, 36, 53, 34) after crop: (1, 36, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_257
# before crop: (1, 33, 51, 34) after crop: (1, 33, 51, 34) spacing: [1. 1. 1.]
#
# hippocampus_302
# before crop: (1, 39, 46, 35) after crop: (1, 39, 46, 35) spacing: [1. 1. 1.]
#
# hippocampus_042
# hippocampus_015
# hippocampus_361
# hippocampus_320
# hippocampus_279
# hippocampus_074
# hippocampus_083
# before crop: (1, 34, 47, 33) after crop: (1, 34, 47, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 50, 34) after crop: (1, 32, 50, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 28, 51, 42) after crop: (1, 28, 51, 42) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 52, 37) after crop: (1, 34, 52, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 50, 36) after crop: (1, 33, 50, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 47, 37) after crop: (1, 42, 47, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 52, 33) after crop: (1, 37, 52, 33) spacing: [1. 1. 1.]
#
# hippocampus_197
# hippocampus_142
# hippocampus_068
# before crop: (1, 31, 51, 38) after crop: (1, 31, 51, 38) spacing: [1. 1. 1.]
#
# hippocampus_234
# hippocampus_308
# before crop: (1, 41, 43, 38) after crop: (1, 41, 43, 38) spacing: [1. 1. 1.]
#
# hippocampus_261
# before crop: (1, 43, 40, 36) after crop: (1, 43, 40, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 49, 38) after crop: (1, 36, 49, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 38) after crop: (1, 40, 48, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 58, 36) after crop: (1, 33, 58, 36) spacing: [1. 1. 1.]
#
# hippocampus_351
# hippocampus_019
# before crop: (1, 35, 51, 35) after crop: (1, 35, 51, 35) spacing: [1. 1. 1.]
#
# hippocampus_133
# before crop: (1, 41, 47, 36) after crop: (1, 41, 47, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 41, 39) after crop: (1, 42, 41, 39) spacing: [1. 1. 1.]
#
# hippocampus_228
# before crop: (1, 36, 48, 37) after crop: (1, 36, 48, 37) spacing: [1. 1. 1.]
#
# hippocampus_164
# hippocampus_251
# hippocampus_375
# hippocampus_033
# before crop: (1, 47, 48, 41) after crop: (1, 47, 48, 41) spacing: [1. 1. 1.]
#
# before crop: (1, 28, 58, 36) after crop: (1, 28, 58, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 48, 33) after crop: (1, 38, 48, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 54, 32) after crop: (1, 34, 54, 32) spacing: [1. 1. 1.]
#
# hippocampus_210
# hippocampus_181
# before crop: (1, 40, 48, 34) after crop: (1, 40, 48, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 49, 33) after crop: (1, 40, 49, 33) spacing: [1. 1. 1.]
#
# hippocampus_216
# hippocampus_212
# before crop: (1, 36, 49, 32) after crop: (1, 36, 49, 32) spacing: [1. 1. 1.]
#
# hippocampus_044
# before crop: (1, 34, 56, 35) after crop: (1, 34, 56, 35) spacing: [1. 1. 1.]
#
# hippocampus_336
# before crop: (1, 33, 48, 38) after crop: (1, 33, 48, 38) spacing: [1. 1. 1.]
#
# hippocampus_048
# hippocampus_316
# before crop: (1, 43, 47, 34) after crop: (1, 43, 47, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 29, 52, 38) after crop: (1, 29, 52, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 51, 37) after crop: (1, 33, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_144
# hippocampus_310
# hippocampus_174
# before crop: (1, 43, 45, 34) after crop: (1, 43, 45, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 55, 37) after crop: (1, 34, 55, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 52, 35) after crop: (1, 38, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_135
# hippocampus_236
# hippocampus_089
# hippocampus_363
# before crop: (1, 38, 49, 32) after crop: (1, 38, 49, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 57, 37) after crop: (1, 35, 57, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 51, 34) after crop: (1, 38, 51, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 52, 38) after crop: (1, 35, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_373
# hippocampus_039
# hippocampus_006
# before crop: (1, 35, 49, 34) after crop: (1, 35, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_259
# before crop: (1, 34, 53, 34) after crop: (1, 34, 53, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 28, 51, 33) after crop: (1, 28, 51, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 52, 35) after crop: (1, 34, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_035
# hippocampus_295
# hippocampus_290
# before crop: (1, 37, 47, 35) after crop: (1, 37, 47, 35) spacing: [1. 1. 1.]
#
# hippocampus_355
# hippocampus_359
# before crop: (1, 40, 49, 35) after crop: (1, 40, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 53, 35) after crop: (1, 36, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 47, 33) after crop: (1, 38, 47, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 49, 35) after crop: (1, 35, 49, 35) spacing: [1. 1. 1.]
#
# hippocampus_263
# before crop: (1, 35, 51, 36) after crop: (1, 35, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_282
# hippocampus_106
# before crop: (1, 38, 46, 34) after crop: (1, 38, 46, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 52, 37) after crop: (1, 32, 52, 37) spacing: [1. 1. 1.]
#
# hippocampus_328
# hippocampus_224
# hippocampus_141
# before crop: (1, 30, 54, 38) after crop: (1, 30, 54, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 48, 37) after crop: (1, 37, 48, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 44, 33) after crop: (1, 42, 44, 33) spacing: [1. 1. 1.]
#
# hippocampus_300
# hippocampus_084
# before crop: (1, 35, 53, 34) after crop: (1, 35, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_390
# before crop: (1, 37, 52, 34) after crop: (1, 37, 52, 34) spacing: [1. 1. 1.]
#
# hippocampus_041
# before crop: (1, 33, 51, 38) after crop: (1, 33, 51, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 51, 36) after crop: (1, 34, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_160
# before crop: (1, 26, 51, 34) after crop: (1, 26, 51, 34) spacing: [1. 1. 1.]
#
# hippocampus_321
# before crop: (1, 34, 46, 34) after crop: (1, 34, 46, 34) spacing: [1. 1. 1.]
#
# hippocampus_060
# before crop: (1, 31, 52, 39) after crop: (1, 31, 52, 39) spacing: [1. 1. 1.]
#
# hippocampus_221
# hippocampus_127
# hippocampus_065
# hippocampus_003
# before crop: (1, 34, 48, 32) after crop: (1, 34, 48, 32) spacing: [1. 1. 1.]
#
# hippocampus_169
# before crop: (1, 31, 55, 38) after crop: (1, 31, 55, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 52, 39) after crop: (1, 37, 52, 39) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 52, 34) after crop: (1, 35, 52, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 45, 36) after crop: (1, 39, 45, 36) spacing: [1. 1. 1.]
#
# hippocampus_093
# before crop: (1, 37, 53, 34) after crop: (1, 37, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_114
# hippocampus_172
# before crop: (1, 39, 50, 38) after crop: (1, 39, 50, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 31, 56, 34) after crop: (1, 31, 56, 34) spacing: [1. 1. 1.]
#
# hippocampus_156
# hippocampus_165
# before crop: (1, 29, 49, 34) after crop: (1, 29, 49, 34) spacing: [1. 1. 1.]
# before crop: (1, 36, 52, 36) after crop: (1, 36, 52, 36) spacing: [1. 1. 1.]
#
#
# hippocampus_193
# before crop: (1, 29, 50, 33) after crop: (1, 29, 50, 33) spacing: [1. 1. 1.]
#
# hippocampus_056
# hippocampus_096
# hippocampus_014
# before crop: (1, 42, 47, 41) after crop: (1, 42, 47, 41) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 47, 34) after crop: (1, 39, 47, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 50, 39) after crop: (1, 40, 50, 39) spacing: [1. 1. 1.]
#
# hippocampus_242
# before crop: (1, 34, 52, 38) after crop: (1, 34, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_177
# before crop: (1, 40, 44, 33) after crop: (1, 40, 44, 33) spacing: [1. 1. 1.]
#
# hippocampus_011
# hippocampus_188
# before crop: (1, 31, 50, 36) after crop: (1, 31, 50, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 54, 37) after crop: (1, 36, 54, 37) spacing: [1. 1. 1.]
#
# hippocampus_148
# hippocampus_233
# hippocampus_366
# hippocampus_231
# before crop: (1, 32, 48, 34) after crop: (1, 32, 48, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 47, 37) after crop: (1, 34, 47, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 51, 33) after crop: (1, 37, 51, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 47, 33) after crop: (1, 42, 47, 33) spacing: [1. 1. 1.]
#
# hippocampus_268
# hippocampus_184
# before crop: (1, 37, 51, 34) after crop: (1, 37, 51, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 51, 37) after crop: (1, 33, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_331
# before crop: (1, 33, 52, 35) after crop: (1, 33, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_333
# hippocampus_215
# before crop: (1, 38, 46, 33) after crop: (1, 38, 46, 33) spacing: [1. 1. 1.]
#
# hippocampus_340
# before crop: (1, 33, 49, 35) after crop: (1, 33, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 46, 35) after crop: (1, 38, 46, 35) spacing: [1. 1. 1.]
#
# hippocampus_264
# before crop: (1, 37, 51, 38) after crop: (1, 37, 51, 38) spacing: [1. 1. 1.]
#
# hippocampus_194
# before crop: (1, 30, 50, 35) after crop: (1, 30, 50, 35) spacing: [1. 1. 1.]
#
# hippocampus_219
# hippocampus_223
# before crop: (1, 39, 45, 37) after crop: (1, 39, 45, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 52, 35) after crop: (1, 37, 52, 35) spacing: [1. 1. 1.]
#
# hippocampus_319
# before crop: (1, 34, 48, 33) after crop: (1, 34, 48, 33) spacing: [1. 1. 1.]
#
# hippocampus_094
# before crop: (1, 38, 50, 38) after crop: (1, 38, 50, 38) spacing: [1. 1. 1.]
#
# hippocampus_376
# before crop: (1, 37, 55, 35) after crop: (1, 37, 55, 35) spacing: [1. 1. 1.]
#
# hippocampus_276
# before crop: (1, 33, 50, 35) after crop: (1, 33, 50, 35) spacing: [1. 1. 1.]
#
# hippocampus_368
# before crop: (1, 40, 55, 38) after crop: (1, 40, 55, 38) spacing: [1. 1. 1.]
#
# hippocampus_175
# before crop: (1, 35, 47, 33) after crop: (1, 35, 47, 33) spacing: [1. 1. 1.]
#
# hippocampus_250
# hippocampus_077
# hippocampus_287
# hippocampus_317
# hippocampus_207
# before crop: (1, 34, 51, 33) after crop: (1, 34, 51, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 45, 47, 35) after crop: (1, 45, 47, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 53, 35) after crop: (1, 33, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 50, 37) after crop: (1, 39, 50, 37) spacing: [1. 1. 1.]
#
# hippocampus_130
# hippocampus_350
# before crop: (1, 40, 49, 35) after crop: (1, 40, 49, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 34, 49, 35) after crop: (1, 34, 49, 35) spacing: [1. 1. 1.]
#
# hippocampus_051
# hippocampus_217
# before crop: (1, 39, 54, 33) after crop: (1, 39, 54, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 27, 53, 38) after crop: (1, 27, 53, 38) spacing: [1. 1. 1.]
#
# hippocampus_132
# before crop: (1, 40, 50, 36) after crop: (1, 40, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_075
# before crop: (1, 41, 47, 32) after crop: (1, 41, 47, 32) spacing: [1. 1. 1.]
#
# hippocampus_067
# hippocampus_387
# before crop: (1, 32, 51, 33) after crop: (1, 32, 51, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 42, 36) after crop: (1, 41, 42, 36) spacing: [1. 1. 1.]
#
# hippocampus_004
# hippocampus_385
# before crop: (1, 38, 52, 36) after crop: (1, 38, 52, 36) spacing: [1. 1. 1.]
#
# hippocampus_378
# before crop: (1, 34, 52, 35) after crop: (1, 34, 52, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 35) after crop: (1, 40, 48, 35) spacing: [1. 1. 1.]
#
# hippocampus_053
# hippocampus_104
# before crop: (1, 35, 51, 37) after crop: (1, 35, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_260
# before crop: (1, 39, 53, 35) after crop: (1, 39, 53, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 29, 53, 35) after crop: (1, 29, 53, 35) spacing: [1. 1. 1.]
#
# hippocampus_299
# hippocampus_205
# hippocampus_244
# before crop: (1, 34, 54, 32) after crop: (1, 34, 54, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 47, 32) after crop: (1, 32, 47, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 53, 38) after crop: (1, 30, 53, 38) spacing: [1. 1. 1.]
#
# hippocampus_155
# before crop: (1, 37, 53, 34) after crop: (1, 37, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_360
# hippocampus_305
# hippocampus_327
# before crop: (1, 30, 49, 34) after crop: (1, 30, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 49, 34) after crop: (1, 37, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 27, 54, 36) after crop: (1, 27, 54, 36) spacing: [1. 1. 1.]
#
# hippocampus_126
# hippocampus_203
# before crop: (1, 43, 44, 39) after crop: (1, 43, 44, 39) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 49, 34) after crop: (1, 38, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_303
# hippocampus_026
# before crop: (1, 38, 48, 35) after crop: (1, 38, 48, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 50, 36) after crop: (1, 36, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_372
# hippocampus_138
# before crop: (1, 34, 50, 36) after crop: (1, 34, 50, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 42, 46, 32) after crop: (1, 42, 46, 32) spacing: [1. 1. 1.]
#
# hippocampus_311
# before crop: (1, 37, 49, 37) after crop: (1, 37, 49, 37) spacing: [1. 1. 1.]
#
# hippocampus_149
# hippocampus_038
# before crop: (1, 32, 49, 33) after crop: (1, 32, 49, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 51, 37) after crop: (1, 35, 51, 37) spacing: [1. 1. 1.]
#
# hippocampus_057
# before crop: (1, 34, 51, 35) after crop: (1, 34, 51, 35) spacing: [1. 1. 1.]
#
# hippocampus_145
# before crop: (1, 33, 53, 36) after crop: (1, 33, 53, 36) spacing: [1. 1. 1.]
#
# hippocampus_045
# before crop: (1, 37, 48, 36) after crop: (1, 37, 48, 36) spacing: [1. 1. 1.]
#
# hippocampus_034
# before crop: (1, 40, 49, 36) after crop: (1, 40, 49, 36) spacing: [1. 1. 1.]
#
# hippocampus_383
# before crop: (1, 29, 55, 33) after crop: (1, 29, 55, 33) spacing: [1. 1. 1.]
#
# hippocampus_374
# hippocampus_049
# hippocampus_108
# hippocampus_036
# hippocampus_157
# hippocampus_292
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 48, 38) after crop: (1, 39, 48, 38) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 51, 36) after crop: (1, 35, 51, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 53, 36) after crop: (1, 37, 53, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 39, 47, 36) after crop: (1, 39, 47, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 52, 38) after crop: (1, 33, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_136
# before crop: (1, 41, 49, 34) after crop: (1, 41, 49, 34) spacing: [1. 1. 1.]
#
# hippocampus_102
# before crop: (1, 32, 55, 36) after crop: (1, 32, 55, 36) spacing: [1. 1. 1.]
#
# hippocampus_008
# hippocampus_025
# before crop: (1, 35, 48, 35) after crop: (1, 35, 48, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 40, 48, 36) after crop: (1, 40, 48, 36) spacing: [1. 1. 1.]
#
# hippocampus_381
# hippocampus_161
# before crop: (1, 37, 49, 33) after crop: (1, 37, 49, 33) spacing: [1. 1. 1.]
#
# before crop: (1, 36, 51, 35) after crop: (1, 36, 51, 35) spacing: [1. 1. 1.]
#
# hippocampus_143
# before crop: (1, 41, 45, 32) after crop: (1, 41, 45, 32) spacing: [1. 1. 1.]
#
# hippocampus_173
# before crop: (1, 32, 53, 35) after crop: (1, 32, 53, 35) spacing: [1. 1. 1.]
#
# hippocampus_125
# before crop: (1, 39, 42, 43) after crop: (1, 39, 42, 43) spacing: [1. 1. 1.]
#
# hippocampus_370
# before crop: (1, 36, 50, 35) after crop: (1, 36, 50, 35) spacing: [1. 1. 1.]
#
# hippocampus_301
# hippocampus_046
# hippocampus_393
# before crop: (1, 36, 50, 31) after crop: (1, 36, 50, 31) spacing: [1. 1. 1.]
#
# before crop: (1, 31, 51, 36) after crop: (1, 31, 51, 36) spacing: [1. 1. 1.]
#
# before crop: (1, 38, 49, 36) after crop: (1, 38, 49, 36) spacing: [1. 1. 1.]
#
# hippocampus_180
# before crop: (1, 36, 45, 37) after crop: (1, 36, 45, 37) spacing: [1. 1. 1.]
#
# hippocampus_146
# hippocampus_124
# before crop: (1, 41, 55, 35) after crop: (1, 41, 55, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 32, 51, 36) after crop: (1, 32, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_337
# before crop: (1, 41, 44, 33) after crop: (1, 41, 44, 33) spacing: [1. 1. 1.]
#
# hippocampus_229
# before crop: (1, 35, 50, 33) after crop: (1, 35, 50, 33) spacing: [1. 1. 1.]
#
# hippocampus_226
# hippocampus_024
# before crop: (1, 28, 51, 32) after crop: (1, 28, 51, 32) spacing: [1. 1. 1.]
#
# before crop: (1, 33, 52, 38) after crop: (1, 33, 52, 38) spacing: [1. 1. 1.]
#
# hippocampus_091
# before crop: (1, 29, 51, 36) after crop: (1, 29, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_171
# before crop: (1, 28, 56, 35) after crop: (1, 28, 56, 35) spacing: [1. 1. 1.]
#
# hippocampus_163
# before crop: (1, 44, 47, 36) after crop: (1, 44, 47, 36) spacing: [1. 1. 1.]
#
# hippocampus_329
# before crop: (1, 32, 53, 34) after crop: (1, 32, 53, 34) spacing: [1. 1. 1.]
#
# hippocampus_354
# before crop: (1, 32, 50, 36) after crop: (1, 32, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_325
# before crop: (1, 40, 51, 35) after crop: (1, 40, 51, 35) spacing: [1. 1. 1.]
#
# hippocampus_190
# hippocampus_326
# hippocampus_389
# before crop: (1, 32, 49, 34) after crop: (1, 32, 49, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 30, 52, 37) after crop: (1, 30, 52, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 41, 49, 36) after crop: (1, 41, 49, 36) spacing: [1. 1. 1.]
#
# hippocampus_225
# before crop: (1, 26, 53, 33) after crop: (1, 26, 53, 33) spacing: [1. 1. 1.]
#
# hippocampus_289
# before crop: (1, 36, 49, 35) after crop: (1, 36, 49, 35) spacing: [1. 1. 1.]
#
# hippocampus_227
# before crop: (1, 36, 47, 36) after crop: (1, 36, 47, 36) spacing: [1. 1. 1.]
#
# hippocampus_090
# before crop: (1, 40, 50, 37) after crop: (1, 40, 50, 37) spacing: [1. 1. 1.]
#
# hippocampus_092
# hippocampus_297
# before crop: (1, 28, 49, 38) after crop: (1, 28, 49, 38) spacing: [1. 1. 1.]
#
# hippocampus_356
# before crop: (1, 30, 51, 34) after crop: (1, 30, 51, 34) spacing: [1. 1. 1.]
#
# before crop: (1, 37, 51, 36) after crop: (1, 37, 51, 36) spacing: [1. 1. 1.]
#
# hippocampus_088
# before crop: (1, 35, 52, 40) after crop: (1, 35, 52, 40) spacing: [1. 1. 1.]
#
# hippocampus_020
# hippocampus_235
# hippocampus_358
# before crop: (1, 34, 50, 35) after crop: (1, 34, 50, 35) spacing: [1. 1. 1.]
#
# before crop: (1, 35, 58, 37) after crop: (1, 35, 58, 37) spacing: [1. 1. 1.]
#
# before crop: (1, 43, 46, 36) after crop: (1, 43, 46, 36) spacing: [1. 1. 1.]
#
# hippocampus_335
# before crop: (1, 41, 47, 32) after crop: (1, 41, 47, 32) spacing: [1. 1. 1.]
#
# hippocampus_248
# before crop: (1, 38, 50, 36) after crop: (1, 38, 50, 36) spacing: [1. 1. 1.]
#
# hippocampus_274
# before crop: (1, 40, 40, 35) after crop: (1, 40, 40, 35) spacing: [1. 1. 1.]
#
# hippocampus_309
# before crop: (1, 38, 52, 34) after crop: (1, 38, 52, 34) spacing: [1. 1. 1.]
#
# hippocampus_252
# before crop: (1, 26, 55, 37) after crop: (1, 26, 55, 37) spacing: [1. 1. 1.]
#
# hippocampus_352
# before crop: (1, 35, 51, 38) after crop: (1, 35, 51, 38) spacing: [1. 1. 1.]
#
# hippocampus_098
# before crop: (1, 34, 48, 37) after crop: (1, 34, 48, 37) spacing: [1. 1. 1.]
#
#
#
#
#  Task004_Hippocampus
# number of threads:  (8, 8)
#
# not using nonzero mask for normalization
# Are we using the nonzero mask for normalization? OrderedDict([(0, False)])
# the median shape of the dataset is  [36. 50. 35.]
# the max shape in the dataset is  [47. 59. 43.]
# the min shape in the dataset is  [24. 40. 31.]
# we don't want feature maps smaller than  4  in the bottleneck
# the transposed median shape of the dataset is  [36. 50. 35.]
# generating configuration for 3d_fullres
# {0: {'batch_size': 9, 'num_pool_per_axis': [3, 3, 3], 'patch_size': array([40, 56, 40]), 'median_patient_size_in_voxels': array([36, 50, 35]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}}
# transpose forward [0, 1, 2]
# transpose backward [0, 1, 2]
# Initializing to run preprocessing
# npz folder: /scratch/alif/nnUNet/nnUNet_raw_data_base/nnUNet_cropped_data/Task004_Hippocampus
# output_folder: /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 48, 35)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 28, 49, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 48, 35)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 28, 49, 38)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 47, 35)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 55, 36)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 55, 36)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 47, 35)}
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 32)}
#
#
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 48, 36)}
# after: before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 48, 36)}
#
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 51, 35)}
#
# 1 1222
# 1 2135
# 1 1246
# 1 1390
# 1 1867
# 1 1488
# 1 1324
# 1 2289
# 2 1343
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_017.npz
# 2 1826
# 2 1654
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_075.npz
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_092.npz
# 2 1383
# 2 1583
# 2 1666
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_057.npz
# 2 1622
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_035.npz
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_102.npz
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_045.npz
# 2 1624
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_001.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 36)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 47, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 47, 36)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 53, 34)}
# after: no resampling necessary
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 53, 34)}
#
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 49, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 49, 36)}
#
# 1 1334
# 2 1793
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_058.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 53, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 53, 35)}
#
# 1 1611
# 1 1849
# 1 1888
# 1 2221
# 2 1681
# 2 1660
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_046.npz
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_036.npz
# 2 1468
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_019.npz
# 2 1596
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_104.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 45, 47, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 45, 47, 35)}
#
# 1 1984
# 2 1734
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_077.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 52, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 52, 39)}
#
# 1 1726
# 2 1683
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_060.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 29, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 29, 52, 38)}
#
# 1 1957
# 2 1315
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_048.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 46, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 46, 36)}
#
# 1 2146
# 2 1465
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_020.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 47, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 47, 33)}
#
# 1 1832
# 2 1328
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_105.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 52, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 52, 34)}
#
# 1 1550
# 2 1803
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_003.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 33)}
#
# 1 1650
# 2 1721
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_083.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 36, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 36, 51, 35)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 53, 35)}
# after: 1 1908
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 53, 35)}
#
# 2 1820
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_049.npz
# no resampling necessary
# no resampling necessary
# 1 2044
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 51, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 51, 34)}
#
# 2 1616
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_064.npz
# 1 1578
# 2 1617
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_037.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 46, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 46, 34)}
#
# 1 1712
# 2 1380
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_106.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 53, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 53, 34)}
#
# 1 1748
# 2 1820
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_023.npz
# 1 1762
# 2 1980
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_093.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 52, 36)}
#
# 1 1832
# 2 1866
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_004.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 34)}
#
# 1 1390
# 2 1760
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_084.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 52, 39)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 52, 39)}
#
# 1 1730
# 2 1920
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_065.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 55, 35)}
#
# 1 1911
# 2 2035
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_107.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 52, 38)}
#
# 1 2011
# 2 2019
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_024.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 49, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 49, 38)}
#
# 1 2023
# 2 1808
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_stage0/hippocampus_050.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 55, 35)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 52, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 52, 35)}
#
# no resampling necessary
# no resampling necessary
# 1 1933
# 1 2314
# ...
#
# normalization...
# normalization done
# 1 1959
# 2 1249
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_386.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 49, 34)}
#
# normalization...
# normalization done
# 1 1298
# 2 1633
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_360.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 47, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 47, 32)}
#
# normalization...
# normalization done
# 1 1263
# 2 1269
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_335.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 27, 54, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 27, 54, 36)}
#
# normalization...
# normalization done
# 1 2092
# no resampling necessary
# no resampling necessary
# 2 1551
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_327.npz
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 35)}
#
# normalization...
# normalization done
# 1 1822
# 2 1902
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_351.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 50, 36)}
#
# normalization...
# normalization done
# 1 1733
# 2 1372
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_361.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 47, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 47, 34)}
#
# normalization...
# normalization done
# 1 1298
# 2 1295
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_336.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 30, 54, 38)}
# after: no resampling necessary
# no resampling necessary
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 30, 54, 38)}
#
# normalization...
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 50, 36)}
#
# normalization...
# normalization done
# normalization done
# 1 2371
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 51, 33)}
# after: 1 1751
# 2 1586
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 51, 33)}
#
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_328.npz
# normalization...
# 2 1732
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_372.npz
# normalization done
# 1 1509
# 2 1571
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_387.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 51, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 51, 38)}
#
# normalization...
# normalization done
# 1 1966
# 2 1713
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_352.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 49, 34)}
#
# normalization...
# normalization done
# 1 1763
# 2 1184
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_389.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 51, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 51, 32)}
#
# normalization...
# normalization done
# 1 1415
# 2 1340
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_353.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 49, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 49, 34)}
#
# normalization...
# normalization done
# 1 1882
# 2 1807
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_373.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 53, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 53, 34)}
#
# normalization...
# normalization done
# 1 1937
# 2 1738
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_329.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 39, 48, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 39, 48, 38)}
#
# normalization...
# normalization done
# 1 2123
# 2 1754
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_374.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 55, 35)}
#
# normalization...
# normalization done
# 1 2232
# 2 1765
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_330.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 50, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 50, 36)}
#
# normalization...
# normalization done
# 1 1529
# 2 1383
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_354.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 51, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 51, 38)}
#
# normalization...
# normalization done
# 1 1886
# 2 1366
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_390.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 54, 32)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 54, 32)}
#
# normalization...
# normalization done
# 1 1686
# 2 1536
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_375.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 33, 52, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 33, 52, 35)}
#
# normalization...
# normalization done
# 1 1561
# 2 1633
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_331.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 31, 51, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 31, 51, 36)}
#
# normalization...
# normalization done
# 1 1864
# 2 1818
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_393.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 47, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 47, 33)}
#
# normalization...
# normalization done
# 1 1819
# 2 1516
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_355.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 52, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 52, 38)}
#
# normalization...
# normalization done
# 1 1838
# 2 1668
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_363.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 41, 44, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 41, 44, 33)}
#
# normalization...
# normalization done
# 1 1551
# 2 1702
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_337.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 32, 52, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 32, 52, 36)}
#
# normalization...
# normalization done
# 1 1987
# no resampling necessary
# no resampling necessary
# 2 1827
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_394.npz
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 47, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 47, 37)}
#
# normalization...
# normalization done
# 1 2482
# 2 1497
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_366.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 57, 36)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 57, 36)}
#
# normalization...
# normalization done
# 1 2212
# 2 1939
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_367.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 43, 43, 37)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 43, 43, 37)}
#
# normalization...
# normalization done
# 1 2007
# 2 1616
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_338.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 55, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 55, 35)}
#
# normalization...
# normalization done
# 1 1625
# 2 1956
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_376.npz
# no resampling necessary
# no resampling necessary
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 40, 55, 38)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 40, 55, 38)}
#
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 38, 46, 35)}
# after: normalization...
#  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 38, 46, 35)}
#
# normalization...
# normalization done
# normalization done
# 1 1592
# 1 2593
# 2 1618
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_340.npz
# 2 1808
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_368.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 34, 52, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 34, 52, 35)}
#
# normalization...
# normalization done
# 1 1180
# 2 1577
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_378.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 35, 48, 34)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 35, 48, 34)}
#
# normalization...
# normalization done
# 1 1331
# 2 1257
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_341.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 42, 46, 35)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 42, 46, 35)}
#
# normalization...
# normalization done
# 1 1730
# 2 1705
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_380.npz
# no resampling necessary
# no resampling necessary
# before: {'spacing': array([1., 1., 1.]), 'spacing_transposed': array([1., 1., 1.]), 'data.shape (data is transposed)': (1, 37, 49, 33)}
# after:  {'spacing': array([1., 1., 1.]), 'data.shape (data is resampled)': (1, 37, 49, 33)}
#
# normalization...
# normalization done
# 1 1550
# 2 1602
# saving:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1_2D_stage0/hippocampus_381.npz

# %%
# ! nnUNet_plan_and_preprocess -t 04

# %%
! nnUNet_train 3d_fullres nnUNetTrainerV2 Task004_Hippocampus 0 --npz
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# ###############################################
# I am running the following nnUNet: 3d_fullres
# My trainer class is:  <class 'nnunet.training.network_training.nnUNetTrainerV2.nnUNetTrainerV2'>
# For that I will be using the following configuration:
# num_classes:  2
# modalities:  {0: 'MRI'}
# use_mask_for_norm OrderedDict([(0, False)])
# keep_only_largest_region None
# min_region_size_per_class None
# min_size_per_class None
# normalization_schemes OrderedDict([(0, 'nonCT')])
# stages...
#
# stage:  0
# {'batch_size': 9, 'num_pool_per_axis': [3, 3, 3], 'patch_size': array([40, 56, 40]), 'median_patient_size_in_voxels': array([36, 50, 35]), 'current_spacing': array([1., 1., 1.]), 'original_spacing': array([1., 1., 1.]), 'do_dummy_2D_data_aug': False, 'pool_op_kernel_sizes': [[2, 2, 2], [2, 2, 2], [2, 2, 2]], 'conv_kernel_sizes': [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]}
#
# I am using stage 0 from these plans
# I am using sample dice + CE loss
#
# I am using data from this folder:  /scratch/alif/nnUNet/nnUNet_preprocessed/Task004_Hippocampus/nnUNetData_plans_v2.1
# ###############################################
# loading dataset
# loading all case properties
# ^C
